# %%
import pandas as pd
import mysql.connector
from  mysql.connector import errorcode
import ast

# %%
df_detalles_actores= pd.read_csv("datos_actores/lista_actores_1999_1000_1000.csv")

# %%
lista_tuplas_detalles=[]
for i in range(1990,2024):
    for j in range(1,3):
        try:
            df_detalles_actores= pd.read_csv(f"datos_actores/lista_actores_{i}_1000_{j}000.csv")
        except:
            print(f"lista_actores_{i}_1000_{j}000.csv - no existe")
            break

        for fila in df_detalles_actores.values:
           
            try:
                conocido = ast.literal_eval(fila[2])
            
            except:
                conocido= "No data"
            try:    
                que_hace = ast.literal_eval(fila[3])
                que_hace=", ".join(que_hace)
            except:
                que_hace = "No data"
            lista_tuplas_detalles.append((fila[0], fila[1], conocido[0], que_hace, fila[4]))
# Out:
# lista_actores_1990_1000_1000.csv - no existe
# lista_actores_1991_1000_1000.csv - no existe
# lista_actores_1992_1000_1000.csv - no existe
# lista_actores_1993_1000_1000.csv - no existe
# lista_actores_1994_1000_1000.csv - no existe
# lista_actores_1995_1000_1000.csv - no existe
# lista_actores_1996_1000_1000.csv - no existe
# lista_actores_1997_1000_1000.csv - no existe
# lista_actores_1998_1000_1000.csv - no existe
# lista_actores_1999_1000_2000.csv - no existe
# lista_actores_2000_1000_2000.csv - no existe
# lista_actores_2001_1000_2000.csv - no existe
# lista_actores_2002_1000_2000.csv - no existe
# lista_actores_2003_1000_2000.csv - no existe
# lista_actores_2004_1000_2000.csv - no existe
# lista_actores_2005_1000_2000.csv - no existe
# lista_actores_2006_1000_2000.csv - no existe
# lista_actores_2007_1000_2000.csv - no existe
# lista_actores_2008_1000_2000.csv - no existe
# lista_actores_2009_1000_2000.csv - no existe
# lista_actores_2010_1000_1000.csv - no existe
# lista_actores_2011_1000_1000.csv - no existe
# lista_actores_2012_1000_1000.csv - no existe
# lista_actores_2013_1000_1000.csv - no existe
# lista_actores_2014_1000_1000.csv - no existe

# %%
lista_final_detalles=[]
lista_tuplas_detalles=set(lista_tuplas_detalles)
lista_actores=[]
for tupla in lista_tuplas_detalles:
    lista_actores.append(tupla[0])
    
len(lista_actores)
# Out:
# 21368

# %%
lista_actores[:10]
# Out:
# ['Isaac Rovira',
#  'Gergo Danka',
#  'Seiji Okabe',
#  'Cezmi Baskin',
#  'Lidi Lisboa',
#  'Mischa Barton',
#  'Claire Dubien',
#  'Bárbara Pacheco',
#  'Gene Amoroso',
#  'Freddy Rotterdam']

# %%
duplicados_actores=[actor for actor in lista_actores if lista_actores.count(actor)>1]

# %%
set(duplicados_actores)
# Out:
# {'Adam Hurtig',
#  'Aditi Sharma',
#  'Agni Scott',
#  'Al Thompson',
#  'Alberto Jiménez',
#  'Alejandro Oliva',
#  'Aline Marrero',
#  'Allan Anthony Smith',
#  'Allen Ault',
#  'Allen Dizon',
#  'Amit Itzcar',
#  'Androulla Irakleous',
#  'Angeli Bayani',
#  'Angeliki Papoulia',
#  'Angie Milliken',
#  'Anindya Chatterjee',
#  'Anne Haug',
#  'Anton Nassif',
#  'Appukutty',
#  'Aqeel Ash-Shakoor',
#  'Arthur Chen',
#  'Artie Pasquale',
#  'Aryan Rajesh',
#  'Ashish Warang',
#  'Ashley Springer',
#  'Bachan Pachehra',
#  'Bai-Ke',
#  'Bala Saravanan',
#  'Banlop Lomnoi',
#  'Barbara Thomas',
#  'Baz Black',
#  'Beverly Salviejo',
#  'Bharat Ganeshpure',
#  'Binlong Pan',
#  'Binu Adimali',
#  'Biswanath Basu',
#  'Bobby Gerrits',
#  'Brandon Cantilang',
#  'Brett Houdek',
#  'Brian Chou',
#  'Brian Yang',
#  'Bronsonn Taylor',
#  'Caco Ciocler',
#  'Carl Bressler',
#  'Carlos Aragón',
#  'Carlos Moreno',
#  'Cate Carson',
#  'Celia Au',
#  'Chelese Belmont',
#  'Chhaya Kadam',
#  'Chia-Kuei Chen',
#  'Chris Carlisle',
#  'Chris Rogers',
#  'Chris Victor',
#  'Christiana Leucas',
#  "Christina Jo'Leigh",
#  'Christopher Fisher',
#  'Chuck E Powers',
#  'Cici Lau',
#  'Cindy Vela',
#  'Claire van der Boom',
#  'Cooper Rivers',
#  'Damien Gerard',
#  'Daniel Asher',
#  'Daniele Clements',
#  'Danielle Burr',
#  'Dante Rivero',
#  'Darina Al Joundi',
#  'David Anthony Marshall',
#  'David Mourato',
#  'David N. Donihue',
#  'David Neil Cohen',
#  'Derek Michalak',
#  'Devang Patel',
#  'Diana Charles',
#  'Donncha Crowley',
#  'Douglas Reith',
#  'Dralla Aierken',
#  'Edmund Kwan',
#  'Edson Jean',
#  'Edward Kasper',
#  'Elaine Kao',
#  'Elijah Jones',
#  'Emily Hurson',
#  'Eric Black',
#  'Esnedy Milan Herrera',
#  'Fernando Neves',
#  'Francisco Barreiro',
#  'Francisco Reyes',
#  'Gail Bean',
#  'Gail Payne',
#  'Ganapathi',
#  'Gareth R.T. Owen',
#  'Gareth Root',
#  'Geetha',
#  'Geoff Stults',
#  'Gerold Wunstel',
#  'Giampaolo Samà',
#  'Gilles Plouffe',
#  'Giovanni Cirfiera',
#  'Giovanni De Giorgi',
#  'Girija Lokesh',
#  'Gogó Andreu',
#  'Gold Aceron',
#  'Grace Glowicki',
#  'H.G. Dattatreya',
#  'Hakeem Sharif',
#  'Hannah Gross',
#  'Hannah Vanderheide',
#  'Hao Xiang',
#  'Heeba Shah',
#  'Heidi Schooler',
#  'Henry LeBlanc',
#  'Hélène Seuzaret',
#  'Ida Anderson',
#  'Ilavarasu',
#  'Iman Sedaghat',
#  'Isaac Saviñón',
#  'Iyad Hajjaj',
#  'Jack Gore',
#  'Jahbril Cook',
#  'James Boss',
#  'James Melville',
#  'Jason Behr',
#  'Jason Iannacone',
#  'Jason Selvig',
#  'Jaswinder Gardner',
#  'Javon Bates',
#  'Jay Manalo',
#  'Jeanine Bartel',
#  'Jelel Eddine Saadi',
#  'Jerome Ponce',
#  'Jesse James Youngblood',
#  'Jinshan Liu',
#  'Joaquin Domagoso',
#  'Joey Ruggiero',
#  'John J. Concado',
#  'John Reign',
#  'Jordan Allen Bell',
#  'José Sefami',
#  'Julie Bevan',
#  'Juliette Bennett',
#  'Justin McCammom',
#  'Kaori Takeshita',
#  'Karim Theilgaard',
#  'Karishma Ahluwalia',
#  'Kate Ginna',
#  'Katrina Norman',
#  'Katya Molchanova',
#  'Kelechi Udegbe',
#  'Kester Lovelace',
#  'Kirk E. Kelleykahn',
#  'Kottayam Ramesh',
#  'Krishna Kumar',
#  'Kristy Butler',
#  'LaToyia Brown',
#  'Laara Sadiq',
#  'Lal Bahadur Prajapati',
#  'Lary Chary',
#  'Laura Ellis',
#  'Levi Fiehler',
#  'Lidiya Liberman',
#  'Lina Pearson',
#  'Lisa Gastoni',
#  'Liz Waters',
#  'Lizelle Gutierrez',
#  'Logan A. Ryan',
#  'Lola Perier',
#  'Lou Martini Jr.',
#  'Louie DiDonato',
#  'Louis Dempsey',
#  'Lucinda Rhodes Thakrar',
#  'M.R. Gopakumar',
#  'MJ Cayabyab',
#  'Maddalena Ischiale',
#  'Madeleine Coghlan',
#  'Mahmood Hashmi',
#  'Mahmud Alam',
#  'Mahogany Darkberry',
#  'Manikuttan',
#  'Manjunath Hegde',
#  'Margot Bancilhon',
#  'Maria Grazia Di Meo',
#  'Mariah Inger',
#  'Marie Bos',
#  'Marilyn Lima',
#  'Marissa Anita',
#  'Marit Nissen',
#  'Matt Gerald',
#  'Matthew Rhodes',
#  'Mauricio Isaac',
#  'May-Linda Kosumovic',
#  'Mellanie Hubert',
#  'Michael Harris',
#  'Michael Jackson',
#  "Michael O'Hare Wallace",
#  'Michael Rene Walton',
#  'Michael Sifain',
#  'Michelle Coverley',
#  'Michelle Vogel',
#  'Miguel Angel De Luca',
#  'Mikayla Kane',
#  'Mo Anouti',
#  'Mohd. Zeeshan Ayyub',
#  'Montetré',
#  'Morgan Lindholm',
#  'Nader Khademi',
#  'Navas Vallikkunnu',
#  'Nick Bartlett',
#  'Nigel Akkara',
#  'Nima Shahrokh Shahi',
#  'Noa Lindberg',
#  'Nobunaga Shimazaki',
#  'Omar Leyva',
#  'Omar Robau',
#  'Omar Santiago',
#  'Oscar Ganem',
#  'Otto Sanchez',
#  'Pablo Rodriguez',
#  'Padma Vaasanthi',
#  'Palak Jain',
#  'Pat Deery',
#  'Paul Bridger',
#  'Paul Carganilla',
#  'Pedro Correa',
#  'Pete Antico',
#  'Phuong Kubacki',
#  'Pradeep Patwardhan',
#  'Pranali Ghoghare',
#  'Prithvik Pratap',
#  'Queen Key',
#  'Quinten Brown',
#  'Radha Ravi',
#  'Rajeev Kanakala',
#  'Rajit Kapoor',
#  'Rama',
#  'Ranjith',
#  'Rashad Anabtawi',
#  'Rebecca Todd',
#  'Rhona Mitra',
#  'Richard Gleason',
#  'Robert Knott',
#  'Robin F. Baker',
#  'Romana Vrede',
#  'Royel Augustine',
#  'Ruth Hayes',
#  'Sahajak Boonthanakit',
#  'Salvador Benavides',
#  'Sam Humphrey',
#  'Sam Keeley',
#  'Sam Littlefield',
#  'Sammi Rotibi',
#  'Sandra Foisy',
#  'Sangili Murugan',
#  'Santosha Nicole',
#  'Sarah Beck Mather',
#  'Sarah Dawson',
#  'Sarah J. Cornelius',
#  'Seiko Higuma',
#  'Sergey Romanovich',
#  'Shady Srour',
#  'Shan MacDonald',
#  'Shane Paul McGhie',
#  'Sharib Hashmi',
#  'Shawntell Anderson',
#  'Shivaji Guruvayoor',
#  'Shobharaj',
#  'Shôtarô Mamiya',
#  'Siamak Ansari',
#  'Solomon Gibson III',
#  'Sonu Saini',
#  'Srikant Murali',
#  'Steph Langnas',
#  'Steve Davis',
#  'Steve Laplante',
#  'Steve McAuley',
#  'Sudheer Karamana',
#  'Sudhi Koppa',
#  'Sue Rock',
#  'Suzanne Shea Reed',
#  'Sveinn Ólafur Gunnarsson',
#  'Syd Stauffer',
#  'Tabla Nani',
#  'Tammi Rogers',
#  'Tara Mallen',
#  'Tejinder',
#  "Thomas J. O'Brien",
#  'Thomas Poarch',
#  'Tim Heidecker',
#  'Timon Kyle Durrett',
#  'Tommy G. Kendrick',
#  'Tomoko Karina',
#  'Tope Tedela',
#  'Travis Cure',
#  'Vanina Kondova',
#  'Vicky Hernández',
#  'Vidhi Chitalia',
#  'Vijilesh Karayad',
#  'Vimal',
#  'Vinay Varma',
#  'Vincent Leclerc',
#  'Vinnie Coppola',
#  'Will Brill',
#  'Will Brisbin',
#  'Will F. Young',
#  'William Bloomfield',
#  'Yayo Aguila',
#  'Yoo-Bin Sung',
#  'Youhao Zhang',
#  'Yufang Wu',
#  'Yutaka Takeuchi',
#  'Zack Gold',
#  'Zakir Hussain',
#  'Zamantha Díaz',
#  'Álvaro Guerrero'}

# %%
for tupla in lista_tuplas_detalles:
    if tupla[0] not in set(duplicados_actores): 
        if tupla[0] is not None:
            lista_final_detalles.append(tupla)
            for elemento in tupla:
                if elemento == "Nan" or not elemento:
                    print(elemento)
                    elemento= "No data"

# %%
len(lista_tuplas_detalles)
# Out:
# 21368

# %%
lista_tuplas_detalles=set(lista_tuplas_detalles)

# %%
cnx = mysql.connector.connect(user="root",
                               password="AlumnaAdalab",
                               host="localhost", database = "bho_peliculas")

mycursor = cnx.cursor()

sql_detalles = "INSERT INTO datos_interpretes (nombre_interprete, año_nacimiento, se_conoce_por, que_hace, premios) VALUES (%s, %s, %s, %s, %s)"

try:
    mycursor.executemany(sql_detalles, lista_final_detalles)
    cnx.commit()
    print(mycursor.rowcount, "registros insertados")
        
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
    print("peliculas - error inserción")
# Out:
# 1048 (23000): Column 'nombre_interprete' cannot be null
# Error Code: 1048
# SQLSTATE 23000
# Message Column 'nombre_interprete' cannot be null
# peliculas - error inserción

# %%
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
