# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import random


from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------

pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %%
def from_csv_to_lists(csv):
  """
    Esta función toma una archivo csv y los pasa a lista de tuplas.
    
    Args:
    - csv: archivo csv.

    Returns:
    - list(df.itertuples(index=False, name=None)): lisat de tuplas
    """
  #lee el csv y lo pasa  a dataframe
  df = pd.read_csv(csv)
  try:
    df = df.drop('Unnamed: 0', axis=1)
  except:
    pass
  #devuelve lisat de tuplas
  return list(df.itertuples(index=False, name=None))

# %%
# ACTORES únicos:
def actores_unicos(lista_tupla_actores):
    """
    Esta función toma una lista de tuplas de (id pelicula y 10 actores principales de la pelicula) y devuelve una lista de actores únicos.
    
    Args:
    - lista_tupla_actores: lista de tuplas de 10 actores principlaes de una peli (id pelicula, actor1-actor10) depues de pasar por la funcion datos_imdb().

    Returns:
    - set(actores): un ser de todos los actores únicos. 
    """
    actores=[]
    for tupla in lista_tupla_actores:
        for actor in tupla[1:]:
            actores.append(actor)
    return set(actores)

# %%
#Informacion actores
def datos_actores(lista_actores):
    """
    Esta función toma una lista de actores y busca información de cada actor en imdb.

    Args:
    - lista_actores: lista de actores (lista de actores que viene de pasar por la funcion datos_imdb() y actores_unicos()

    Returns:
    - detalles_actores: lista de datos de cada actor en una tupla (nombre actor, año nacimiento, conocido por, que hace, premios oscar)
    """

    driver = webdriver.Chrome()

    detalles_actores = []
    detalles_actor = []

    num = 1
    for actor in lista_actores[:1001]:

        driver.maximize_window()
        driver.get("https://www.imdb.com/")

        sleep(0.5)
        print(f"{num}. {actor}")
        try:
            #Escribe el nombre del actor en el buscador
            driver.find_element("css selector", "#suggestion-search").send_keys(actor, Keys.ENTER)
        except:
            driver.get("https://www.imdb.com/")
            driver.find_element("css selector", "#suggestion-search").send_keys(actor, Keys.ENTER)
        
        sleep(0.5)
        try:
            try:
                try:
                    try:
                        driver.find_element("css selector", '#__next > main > div.ipc-page-content-container.ipc-page-content-container--full.sc-383f2ac5-0.bfcGjo > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(3) > div.sc-17bafbdb-2.ffAEHI > ul > li:nth-child(1) > div.ipc-metadata-list-summary-item__c > div > a').click()
                    except:
                        driver.find_element("css selector", 'li.find-name-result:nth-child(1) > div:nth-child(2) > div:nth-child(1) > a:nth-child(1)').click()
                except:
                    driver.find_element("css selector", '.find-name-result > div:nth-child(2) > div:nth-child(1) > a:nth-child(1)').click()
            except:
                driver.find_element("css selector", '#__next > main > div.ipc-page-content-container.ipc-page-content-container--full.sc-872d7ac7-0.fqEQWL > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(4) > div.sc-17bafbdb-2.iUyFfD > ul > li:nth-child(1) > div.ipc-metadata-list-summary-item__c > div > a').click()
        except: 
                pass   
        try:     
            try:
                que_hace = driver.find_element("css selector", '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-3.jJsEuz > div > ul').text
                que_hace = que_hace.split('\n')
            
            except:
                que_hace = driver.find_element("css selector", '.sc-7f1a92f5-4').text
                que_hace = que_hace.split('\n')
        except:
            que_hace = 'No data'  
        print(f"que hace: {que_hace}")
            
        try:
            try:
                try:    
                    try:    
                        try:
                            conocido = driver.find_element("css selector", '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > div > section > div > div.sc-9178d6fe-1.kFxVZc.ipc-page-grid__item.ipc-page-grid__item--span-2 > div.celwidget > section:nth-child(1) > div.sc-a6d4b6c0-0.jGufEe').text
                            conocido = conocido.split('\n')[0::4]
                        except:
                            conocido = driver.find_element("css selector", '.ipc-sub-grid--page-span-2').text
                            conocido = conocido.split('\n')[0::4]
                    except:
                        conocido = driver.find_element("xpath", '/html/body/div[2]/main/div/section[1]/div/section/div/div[1]/div[3]/section[1]/div[2]/div/div[2]').text
                        conocido = conocido.split('\n')[0::4]
                except:
                    conocido = driver.find_element("xpath", '/html/body/div[2]/main/div/section[1]/div/section/div/div[1]/div[4]/section[1]/div[2]/div/div[2]').text
                    conocido = conocido.split('\n')[0::4]
            except:
                conocido = driver.find_element("css selector", '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.fSJiHR > div > section > div > div.sc-9178d6fe-1.fqVKQb.ipc-page-grid__item.ipc-page-grid__item--span-2 > div.celwidget > section:nth-child(1) > div.sc-a6d4b6c0-0.bBRhdF > div > div.ipc-sub-grid.ipc-sub-grid--page-span-2.ipc-sub-grid--wraps-at-above-l.ipc-shoveler__grid').text
                conocido = conocido.split('\n')[0::4]                   
                  
        except:
            conocido = 'No data'
        print(f"conocido: {conocido}")

        try:
            try:
                año = driver.find_element("css selector", '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-4.ecgcFy > div.sc-e226b0e3-6.hfusNC > div.sc-e226b0e3-11.jSQoAO > section > aside > div > span:nth-child(2)').text.split(' ')[-1]
            
            except:
                año = driver.find_element("css selector", 'aside.sc-dec7a8b-0:nth-child(1) > div:nth-child(1) > span:nth-child(2)').text.split(' ')[-1]
        except:
            año = 'No data'
        print(f"año: {año}")    

        try:
            try:
                premios = driver.find_element("css selector", '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > div > section > div > div.sc-9178d6fe-1.kFxVZc.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(3) > div > ul > li > a.ipc-metadata-list-item__label.ipc-metadata-list-item__label--link').text
                if premios == 'Premios':
                    premios = 'Sin Oscar'
            except:
                premios = driver.find_element("css selector", 'ul.ipc-metadata-list:nth-child(2) > li:nth-child(1) > a:nth-child(1)').text
                if premios == 'Premios':
                    premios = 'Sin Oscar'
        except:
            premios = 'Sin oscar'
        print(f"premios: {premios}")
        #nombre actor, año nacimiento, conocido por, que hace, premios oscar
        detalles_actor = (actor, año, conocido, que_hace, premios)

        detalles_actores.append(detalles_actor)
        num += 1
    return detalles_actores

# %%
#csv de los actores desde las peliculas buscadas en imdb a lista de actores únicos
actores_peliculas_2009_1000 = from_csv_to_lists('actores_peliculas_2009_1000.csv')
lista_actores_imdb_2009_1000 = actores_unicos(actores_peliculas_2009_1000)
lista_actores_imdb_2009_1000 = list(lista_actores_imdb_2009_1000)
lista_actores_imdb_2009_1000
# Out:
# ['Rachel Bell',
#  'Bjørn Sundquist',
#  'Yejin Jeong',
#  'Chengwei Ren',
#  'Manabu Oshio',
#  'Lynette Curran',
#  'Jhilmil Hazrika',
#  'Uttar Kumar',
#  'Geoff Falk',
#  'Shalim Ortiz',
#  'Moa Silén',
#  'Leon Seidel',
#  'Xango Henry',
#  'Deneb Catalan',
#  'David Proval',
#  'Deb Mukherjee',
#  'Jason Schwartzman',
#  'Rhys Thomas',
#  'Alejandro de la Madrid',
#  'Kostas Koronaios',
#  'Marco Serralta',
#  'Marc Blucas',
#  'Nicolette Doke',
#  'Kathleen Munroe',
#  'Brendan Miller',
#  'Kestie Morassi',
#  'Gary Beadle',
#  'Don Hahn',
#  'Luke Treadaway',
#  'Trevor Richardson',
#  'Nebojsa Milovanovic',
#  'Sofia Vassilieva',
#  'Juno Temple',
#  'Melia Renee',
#  'Catherine Dyer',
#  'Francis Renaud',
#  'Ariel Gade',
#  'Eric Allan Kramer',
#  'Driss Roukhe',
#  'Sneha',
#  'Ric Maddox',
#  'Marylouise Burke',
#  'Juli Alexandrov',
#  'Jean-Pierre Léaud',
#  'Frederick Weller',
#  'Brad Kranich',
#  'Rhonda Aldrich',
#  'Leah Grimsson',
#  'Edica Casanova',
#  'Maria Ribera',
#  'Michael Teigen',
#  'October Moore',
#  'Trish Egan',
#  'Jack Kyle',
#  'Jill K. Allen',
#  'Zen Ledden',
#  'Paul Calderon',
#  'Cheech Marin',
#  'Bettina Engelhardt',
#  'Nathaniel Brown',
#  'Alyy Khan',
#  'Michael McElhatton',
#  'Daphne Khoury',
#  'Kankurô Nakamura',
#  'Juan Pablo Arias Barrón',
#  'Lun Zhang',
#  'Vienna K. Bradley',
#  'Karine Vanasse',
#  'Peter Bryant',
#  'Jere Burns',
#  'Alia Rhiana Eckerman',
#  'Don Wallace',
#  'Paul Garrett',
#  'Takao Handa',
#  'Suzanne VanDeMark',
#  'Siouzana Melikian',
#  'Frank Howson',
#  'Angelo Custino',
#  'Kôichi Satô',
#  "Raymond O'Connor",
#  'Henry David',
#  'André Barbosa',
#  'Alia Shawkat',
#  'Emilia Schüle',
#  'James LaMarr',
#  'David Svehlík',
#  'Sophie Nyweide',
#  'Jennifer Couch',
#  'Agathe Bonitzer',
#  "Scott O'Donnell",
#  'Antonio Wannek',
#  'Malin Akerman',
#  'Elisabeth Röhm',
#  'Annette Bening',
#  'Ekaterina Davydova-Tongur',
#  'Ron Perlman',
#  'Monica McShane',
#  'Jelena Stupljanin',
#  'Andreína Olivarí',
#  'Josh Mostel',
#  'Ofer Hayoun',
#  'Ed Spear',
#  'Marie Black',
#  'Lisa Chung',
#  'Marie-Françoise Audollent',
#  'Til Schweiger',
#  'Jerome Smith',
#  'Eva Mazauric',
#  'Gloria de Jesús',
#  'Domiziana Cardinali',
#  'Nicholas Turturro',
#  'Isak Férriz',
#  'Kirti Chauhan',
#  'Melanie Lynskey',
#  'Eamon Glennon',
#  'Kamal Sidhu',
#  'Ben Shenkman',
#  'Erica Rivas',
#  'Matthew Gray Gubler',
#  'Donnie Castillo',
#  "Bobb'e J. Thompson",
#  'Tetsuji Tamayama',
#  'Max Watson',
#  'Ernie Ko',
#  'David Anzuelo',
#  'Virginie Ledoyen',
#  'Darwin Barney',
#  'Chantal Contouri',
#  'Rich Foran',
#  'Michael Panes',
#  'Katrina Walker',
#  'Etsushi Toyokawa',
#  'Bárbara Lazón',
#  'Ingrid Nilson',
#  'Hugo Silva',
#  'Anastasia Baboussouras',
#  'Sven Nordin',
#  'Josie Gammell',
#  'Uno Kanda',
#  'Jean-Paul Girardot',
#  'Nicholas Lea',
#  'David Barlow',
#  'Natalie Slevin',
#  'Sanli Ozlen',
#  'Danny Denzongpa',
#  'Ruth Bradley',
#  'Alexandre Borges',
#  'Michael Rivera',
#  'Shu Guang Liang',
#  'Priyanka Chopra Jonas',
#  'Jamison Haase',
#  'Steven Brown',
#  'Rachael Kemery',
#  'Maarten Stevenson',
#  'Ben Barnes',
#  'Natali Broods',
#  'Khris Kaneff',
#  'Catarina Wallenstein',
#  'Sergey Chonishvili',
#  'Marcio Vito',
#  'Peggy Lukac',
#  'Samantha Morton',
#  'Sammy Sheik',
#  'Lucy McMichael',
#  'Caseyarnoux Charlot',
#  'Jesse Tyler Ferguson',
#  'Colleen Camp',
#  'Amitabh Srivastava',
#  'Jon Kabira',
#  'Brennan Brown',
#  'Kevin Indio Copeland',
#  'Rula Blanco',
#  'Michele Matheson',
#  'Salli Richardson-Whitfield',
#  'Arne Boysen',
#  'Gordon Currie',
#  'Parikshit Sahni',
#  'Bruno Blairet',
#  'John Lasseter',
#  'Aarti Chhabria',
#  'Ken Clark',
#  'Lauren Weedman',
#  'Al Roker',
#  'Adán Rodríguez',
#  'Roselyn Sanchez',
#  'Michael Graziadei',
#  'Pooja Bhatt',
#  'Kali Rocha',
#  'Peter Demelo',
#  'Guillermo Villegas',
#  'Catherine Bruhier',
#  'Romana Abercromby',
#  'Jean Reno',
#  'Marc Oliver Mögling',
#  'Tom Cameron',
#  'Rodolphe Pauly',
#  'John Hambrick',
#  'Cheng-yang Wang',
#  'Lucy Adden',
#  'Gyton Grantley',
#  'Dominique Vandenberg',
#  'Andrea Reimer',
#  'Bevin Hamilton',
#  'Antonino Bruschetta',
#  'Teri Hatcher',
#  'Bernie Hodges',
#  'Ethel Rojo',
#  'Pepa Pedroche',
#  'Mikel Sarah Lambert',
#  'Glória Pires',
#  'Kerris Dorsey',
#  'Alex Scott',
#  'Kerri Hellmuth',
#  'Alwara Höfels',
#  'Danielle Garavaglia',
#  'Alexander Held',
#  'Laurent Capelluto',
#  'Yancey Arias',
#  'Yvan Attal',
#  'Fouad Habash',
#  'Alex van Warmerdam',
#  'Marc Zwinz',
#  'Mirela Naska',
#  'Aasif Mandvi',
#  'Mattia Zaccaro',
#  'Marcelo Armand',
#  'Petar Sekulic',
#  'Isabella Rossellini',
#  'Ekin Cheng',
#  'Carson Grant',
#  'Stephen Root',
#  'Laurent Larrieu',
#  'Lauren Gleason',
#  'Kristin Chenoweth',
#  'Eriko Satô',
#  'Kim Hye-ja',
#  'Paul Kelly',
#  'Michael Becht',
#  'Antti Reini',
#  'Michael Showers',
#  'Jose Candelario',
#  'Iza Calzado',
#  'François Marthouret',
#  'Maynor Alvarado',
#  'Jamie Foxx',
#  'Kirsten Berman',
#  'André Hennicke',
#  'Carolina Bonetti',
#  'Latichia Brown',
#  'Kate Arrington',
#  'Bujar Lako',
#  'Christo Jivkov',
#  'Rosa Isabel Lorenzo',
#  'Greg Timmermans',
#  'Kieran Culkin',
#  'Moisés Acevedo',
#  'Perla Bautista',
#  'Eva Birthistle',
#  'Alberta Watson',
#  'Mikijirô Hira',
#  'Saurabh Shukla',
#  'Kristanna Loken',
#  'Katrin Sass',
#  'Tom Mannion',
#  'Parris Biggs',
#  'Bryony Seth',
#  'Milka Ahlroth',
#  'Alexandru Potocean',
#  'Thekla Reuten',
#  'Sandra Alves',
#  'Jeremy Sumpter',
#  'Thomas Lennon',
#  'Paul Hogan',
#  'Tyrone LaForrest',
#  'Amanda Fuller',
#  'Heinz-Josef Braun',
#  'Shazia Pascal',
#  'Pat Fisher',
#  'Collette Wolfe',
#  'Grete Havnesköld',
#  'József Varga',
#  'Tony Devon',
#  'Rahul Dev',
#  'Madeleine Greaves',
#  'Franziska Weisz',
#  'Pia Röver',
#  'Thomas Frere',
#  'Kenneth Welsh',
#  'Ving Rhames',
#  'Michelle Belegrin',
#  'Louis Mustillo',
#  'Devin DiGonno',
#  'Murli Sharma',
#  'Ann Perry Wallace',
#  'Peter Franzén',
#  'Spyros Fokas',
#  'Adam Gregory',
#  'Hans Petter Hansen',
#  'Josh Pais',
#  'Sam Murphy',
#  'Anatole Taubman',
#  'Jun Kunimura',
#  'Silvio Pollio',
#  'Armin Mueller-Stahl',
#  'Xochiti Guzman',
#  'Frank Vincent',
#  'Beyoncé',
#  'Orhan Whyte',
#  'Gerry Mendicino',
#  'Sheung-ching Lee',
#  'Werner De Smedt',
#  'Helena Vierikko',
#  'Mo Byrnes',
#  'Paige Cooper',
#  'Rusty Schwimmer',
#  'Isaiah Bobo',
#  'George Russo',
#  'Neri Marcorè',
#  'Michael Farris',
#  'Rosemary De Angelis',
#  'Gord Rand',
#  'Masaya Kikawada',
#  'Esmond Chung',
#  'James Wilby',
#  'Vanessa Streiff',
#  'Peter Haber',
#  'Letícia Tavares',
#  'Jasen Swafford',
#  'John Gleeson Connolly',
#  'Fazeng Guo',
#  'Amy Rogers',
#  'Braxton Davis',
#  'Misty Madden',
#  'Jess Weixler',
#  'Patricia Belcher',
#  'King Jeter',
#  'Justin Bradley',
#  'Marc D. Donovan',
#  'Paul Schneider',
#  'C.R. Simha',
#  'Alvin Addo-Quaye',
#  'Do-rim Choi',
#  'Wendy Playfair',
#  'Karoline Herfurth',
#  'Zack Bennett',
#  'Delillo Gary',
#  'Gino Cafarelli',
#  'Christopher Lambert',
#  'Marcia Gay Harden',
#  'Ervin Nagy',
#  'Rossana Camhi',
#  'Efe Toptan',
#  'Freya Parks',
#  'Cosmo Pfeil',
#  'Stephen Lang',
#  'Allyson Muñoz',
#  'Rakhi Sawant',
#  'Manoj K. Jayan',
#  'Peter Easterbrook',
#  'Rie Rasmussen',
#  'Peter Kurth',
#  'Natasa Janjic Medancic',
#  'Curtis Grafton',
#  'Christopher Cass',
#  'Leo Anderson Akana',
#  'James Fox',
#  'Eric Woolfe',
#  'Geneviève Mnich',
#  'James L. Ward',
#  'Elizabeth Marvel',
#  'Loïc Peckels',
#  'Reese Alexander',
#  'Hilal Kaboub',
#  'Jason Britt',
#  'Valentina Vargas',
#  'Sara Raftery',
#  'Diana Gómez',
#  'Bimba Bosé',
#  'Connor Joss',
#  'Stephanie Marois',
#  'Nobu Imai',
#  'Lee Shin',
#  'Andrei Aradits',
#  'Joanne Whalley',
#  'Vladimir Rajcic',
#  'Kevin Isola',
#  'Sandy Walsh',
#  'John Filmanowicz',
#  'Zeca Cenovicz',
#  'Mélanie Doutey',
#  'Won Bin',
#  'Jacinda Barrett',
#  'Jeff Daniel Phillips',
#  'Marshal Hilton',
#  'Sabine Timoteo',
#  'Dipti Mehta',
#  'Léa Wiazemsky',
#  'Mark Tintner',
#  'Andrew Sensenig',
#  'Katrina Halili',
#  'Tamsin Greig',
#  'Ingrid Strelkoff',
#  'Dave Shalansky',
#  'Diego Leske',
#  'Mark DiConzo',
#  'Bernhard Baron Boneberg',
#  'Bill Dow',
#  'Lucie Hollmann',
#  'Mikos',
#  'Harrison Ford',
#  'Michael Ralph',
#  'Rachael Roberts',
#  'Mickey Cottrell',
#  'Michael Masini',
#  'Clarence Felder',
#  'Ken Duken',
#  'Lou Taylor Pucci',
#  'Brandan Halpin',
#  'Makka Kleist',
#  'Curtiss Cook',
#  'Stephon Fuller',
#  'Juliette Lewis',
#  'Shalom Michaelshwilli',
#  'Calvin Walton',
#  'Ramzi Abed',
#  'Eric Gilliland',
#  'Gloria Romero',
#  'Nicky Bell',
#  'Ayse Ersöz',
#  'Daniel Stewart',
#  '2raumwohnung',
#  'Sándor Berettyán',
#  'Pip Torrens',
#  'Norma Lazareno',
#  'Paul Bamgbose',
#  'Karl Sarafidis',
#  'Brent Smiga',
#  'Nathan Baesel',
#  'Rudy Ramos',
#  'Briana Feehan',
#  'Donna Daley',
#  'Hackjin Mun',
#  'Rachel Levine',
#  'Victoria Tennant',
#  'Scott Wilson',
#  'Bernd Tauber',
#  'Evan Ellingson',
#  'Rachel Blanchard',
#  'Johann von Bülow',
#  'Giannis Harismaidis',
#  "Julie 'Jules' Urich",
#  'Bas Keijzer',
#  'Will Green',
#  'Anna Kerth',
#  'Yash Tonk',
#  'Julia Beatty',
#  'Michael Dunston',
#  'Douglas De Souza',
#  'Gérard Watkins',
#  'Wayne Duvall',
#  'Francis Capra',
#  'Alexandra Gentil',
#  'Eva Morkeset',
#  'Heloise Baker',
#  'Stephen Dorff',
#  'Hannah Cowley',
#  'Chuan Wang',
#  'Nicolò Morselli',
#  "Gina D'Ercoli",
#  'Alizeta Congo',
#  'Jason Coleman',
#  'Daniel Duval',
#  'Cheryl Noe',
#  'Bingbing Fan',
#  'Luz Mando',
#  'Amy Adams',
#  'Miriam Isa',
#  'Maude Apatow',
#  'Bebe Neuwirth',
#  'Jong-seok Kim',
#  'Vishal Bahl',
#  'Heather Chasen',
#  'Melissa Holroyd',
#  'Rita Tushingham',
#  'Kassianni Austin',
#  'LisaGay Hamilton',
#  'Magda Szubanski',
#  'Salvatore Ficarra',
#  'Haoua Sangare',
#  'Cailee Corbett',
#  'Denise Roberts',
#  'Gonçalo Waddington',
#  'Kai Michael Müller',
#  'Tobie Windham',
#  'Zoë Mannhardt',
#  'Laura Chiatti',
#  'Tomoya Nagase',
#  'Julianna Conforti',
#  'Michael Keseroglu',
#  'Annu Kapoor',
#  'Gijs Naber',
#  'M.J.J. Cashman',
#  'Shamna Kasim',
#  'Chris McHallem',
#  'Neil Pigot',
#  'Steve Mouzakis',
#  'Henry Kingi',
#  'Sira Stampe',
#  'Mario Guerra',
#  'Mariel Hemingway',
#  'Alvin Bellow',
#  'Boði',
#  'Arnie Burton',
#  'Juan Leyrado',
#  'Michael Ray Escamilla',
#  'Marjuta Slamic',
#  'James Frain',
#  'Eleni C. Krimitsos',
#  'Aankha Neal',
#  'Kenyon Glover',
#  'Riley Cole',
#  'Paul Bettany',
#  'Sakiko Fukuhara',
#  'Benedict Wong',
#  'Irina Voronina',
#  'Milena Dravic',
#  'Mehmet Gurleyen',
#  'Walter Massey',
#  'Georgina Avellaneda',
#  'Branko Djuric',
#  'Eita Nagayama',
#  'Laurens Walter',
#  'David Boutin',
#  'Michaël Vander-Meiren',
#  'Mads Sjøgård Pettersen',
#  'Jason Flemyng',
#  'Evan Boymel',
#  'Vinay Pathak',
#  'Asli Ozmel',
#  'Ailton Graça',
#  'R. Michael David',
#  'Diana Gheorghian',
#  'Billy Fenderson',
#  'Oliver Cotton',
#  'Sam Parsonson',
#  'Lew Temple',
#  'Jeff Garretson',
#  'David Avila Lane',
#  'Kathy Bates',
#  'Karen E. Wright',
#  'Adam Johnson',
#  'Billy Burke',
#  'Maurice Blake',
#  'Sari Viitasalo',
#  'Charles Donnelly',
#  'Adriana Mastrángelo',
#  'Anthony Bonaventura',
#  'Cees Geel',
#  'Sue Cremin',
#  'Jane Holman',
#  'Emily Kennard Dunn',
#  'Connie Britton',
#  'Sílvia Lourenço',
#  'Márta Béres',
#  'Katy Tiemann',
#  'Bill DeWitt',
#  'Joy D. Borland',
#  'Ruth Gabriel',
#  'Laura L. Cottrel',
#  'Jamie Dornan',
#  'Anja Jochimsen',
#  'Carina M. Johansson',
#  'Angelika Fink',
#  'Luc Feit',
#  'Max Records',
#  'Josie DiVincenzo',
#  'Basil Hoffman',
#  'Adèle Ado',
#  'Kelsey Asbille',
#  'Ned Beatty',
#  'Vibeke Ankjær',
#  'Javier Oliván',
#  'Kelton Pell',
#  'Anna Klemp',
#  'Rakesh Adiga',
#  'Megan Lee Ethridge',
#  'John Saxon',
#  'Matt Stasi',
#  'Melissa Epps',
#  'Anna Prus',
#  'Sarah Silverman',
#  'Kris Kristofferson',
#  'Dudley Sutton',
#  'Tarun Shukla',
#  'Tiago Rodrigues',
#  'Stefan Lampadius',
#  'Adam Clark',
#  'Stacy Keach',
#  'Tadeu di Pietro',
#  'Marius Weingarten',
#  'Rockmond Dunbar',
#  'Tôru Minegishi',
#  'Meredith Ostrom',
#  'Bojan Lazarov',
#  'Nadja Uhl',
#  'Richard Mylan',
#  'Benedict Cumberbatch',
#  'Maria Stephens',
#  'Fergie',
#  'Nicola Di Pinto',
#  'Danielle Carter',
#  'Ana Kostovska',
#  'Bob Jennings',
#  'Tim Jo',
#  'Sam Jaeger',
#  'Clémence Poésy',
#  'Sera Rinka',
#  'Quese IMC',
#  'Boris Milivojevic',
#  'Peter Tuinman',
#  'Sabrina Le Beauf',
#  'Sam Robards',
#  'Sam Elliott',
#  'Abby Corrigan',
#  'Jarvis Cocker',
#  'James Crabtree',
#  'Khushboo Grewal',
#  'Ian Roberts',
#  'Helge Jordal',
#  'Steven Crowder',
#  'Dina Al-Erhayem',
#  'Volker Bruch',
#  'Stephen Gevedon',
#  'Marie Castelain',
#  'Dan Mailley',
#  'Kimberley Nixon',
#  'Arata Furuta',
#  'Lília Cabral',
#  'Marcos Akiaten',
#  'John Beasley',
#  'Divya Dutta',
#  'Shelley Thomas-Harts',
#  'Jean Simmons',
#  'Tyler Ross',
#  'Henrique Silveira',
#  'Vesa Vierikko',
#  'Jeff Carpenter',
#  'Marcia Laskowski',
#  'Zsolt Trill',
#  'George MacKay',
#  'David House',
#  'Kevin Akers',
#  'Robert Tobin',
#  'Danni Carlos',
#  'Mahesh Raja',
#  'Allen Williamson',
#  'Tony Dalton',
#  'Billy Gallo',
#  'Lukács Bicskey',
#  'Richard Lefebvre',
#  'Billy Jones',
#  'Shawn Roberts',
#  'Vasilisa Barsukova',
#  'Lee Battle',
#  'Matthew Jaeger',
#  'Samantha Farrell',
#  'William Lash',
#  'Lisa Dewey',
#  'Constantine Markoulakis',
#  'Adriana Ugarte',
#  'J.C. Conway',
#  'Alessio Rigo de Righi',
#  'Rory Freedman',
#  'Dominic Rickhards',
#  'Socratis Otto',
#  'Hrishitaa Bhatt',
#  'Alberto Jiménez',
#  'Klaus Maria Brandauer',
#  'Jean-Paul Bathany',
#  'Álvaro Aguilar',
#  'Ekrem Erkek',
#  'Brent Teclaw',
#  'Holmes Osborne',
#  'Bill Hader',
#  'Matt Stern',
#  'John Sessions',
#  'Brendan Coyle',
#  'Christian Vazquez',
#  'Mitsuko Baishô',
#  'Olivia Cuartero-Briggs',
#  'Richard Sammel',
#  'Justice Leak',
#  "Christina Jo'Leigh",
#  'Scout Alter',
#  'Laura Dern',
#  'Shar Jackson',
#  'Rubén Cristiany',
#  'Timo Ottevanger',
#  'Raymond J. Barry',
#  'Jimmy Bennett',
#  'Yutaka Matsushige',
#  'Rosie Shaw',
#  'Jack Kao',
#  'Anna Brüggemann',
#  'Olivier Gourmet',
#  'Pushkar Shrotri',
#  'Sylvia De Fanti',
#  'Peggy Thompson',
#  'Andrea Savo',
#  'Sally Davis',
#  'Russell Crowe',
#  'Levi Holloway',
#  'Hedda Carney',
#  'João Abel Baptista',
#  'Christian Serratos',
#  'Shima Niavarani',
#  'Vanessa Bauche',
#  'Lone Lindorff',
#  'Ethan Rosenfeld',
#  'Byron Lambie',
#  'Tipper Newton',
#  'Cuauhtémoc Duque',
#  'Celina Jaitly',
#  'Erik Saari',
#  'Mete Horozoglu',
#  'Habib Ghuloom',
#  'John Allen',
#  'Jennifer Connelly',
#  'Ashley Antkowiak',
#  'Ljubomir Bandovic',
#  'Fred Nii Amugi',
#  'Jeff Sinasac',
#  'André Gordon',
#  'Mark Adam',
#  'Léane Grimaud',
#  'Ricardo Chavira',
#  'Tamieka Chavis',
#  'Omi Vaidya',
#  'Ilmari Järvenpää',
#  'Stink Fisher',
#  'Stephanie Renee',
#  'Rick Vargas',
#  'Lucien Jean-Baptiste',
#  'Tony Mabesa',
#  'Jesper Svane',
#  'Faizon Love',
#  'Sandy Greenwood',
#  'Erica Soto',
#  'Branden Waits',
#  'Ashley Springer',
#  'Nebojsa Dugalic',
#  'Daniel Baldwin',
#  'Arved Birnbaum',
#  'Susan Spano',
#  'Valentina Carnelutti',
#  'Clovis Cornillac',
#  'Shawna Waldron',
#  'Ryan McGivern',
#  'Zacharias Foppe',
#  'Mike Dunay',
#  'Anian Zollner',
#  'Alexia Fast',
#  'Jeremy Make',
#  'Birol Ünel',
#  'Mickey Sumner',
#  'Anita Reeves',
#  'Ulla Marie Broch',
#  'Leanne Best',
#  'Smita Hai',
#  'Elina Vehkaoja',
#  'Seppi Haimmerer',
#  'Caroline Dhavernas',
#  'Mathew McElhinney',
#  'Mabel Garza',
#  'Sam Coppola',
#  'Sarah Foret',
#  'Shannon Holt',
#  'Wil Rillero',
#  'Johanna Bantzer',
#  'Michael Harrison',
#  'Dany Boon',
#  'Andrew Hawley',
#  'Adelaide João',
#  'Loletta Lee',
#  'Joana de Verona',
#  'Sruthi Lakshmi',
#  'Brett Lee Alexander',
#  'Lawrence Pressman',
#  'Emmanuelle Seigner',
#  'Hashinosuke Nakamura',
#  'Alberto Gimignani',
#  'David Nykl',
#  'Itatí Cantoral',
#  'Laetitia Casta',
#  'Mark Pellegrino',
#  'Mark Duplass',
#  'Cornel West',
#  'Sophie Lowe',
#  'Kathrine Narducci',
#  'Bea Viegas',
#  'Ken Mitsuishi',
#  'Jens Kraßnig',
#  'Irrfan Khan',
#  'Juli Básti',
#  'Alex Klaus',
#  'Fred Dennis',
#  'Jose Rosete',
#  'Kaniha',
#  'Michael Jacques',
#  'J.K. Simmons',
#  'Lucy Punch',
#  'Christina Mauro',
#  'Danni DanDan Gadigan',
#  'Kristyan Ferrer',
#  'Anupam Maanav',
#  'José de Abreu',
#  'Scott Yaphe',
#  'Adam Goldberg',
#  'Wilson Gonzalez',
#  'S.J. Hannah',
#  'Lee Oakes',
#  'Corbin Allred',
#  'Marshall Allman',
#  'Macdara Ó Fátharta',
#  'Fabienne Hadorn',
#  'Thora Birch',
#  'Jason Mercury',
#  'Brian Elerding',
#  'Aida Oset',
#  'Tôru Masuoka',
#  'Amer Alwan',
#  'Reese Romagnoli',
#  'Julie Depardieu',
#  'Denise Ramirez',
#  'Stephanie Niznik',
#  'Brian Lafontaine',
#  'John Henry Cox',
#  'Daisy Kocher',
#  'DeAnne Elkin',
#  'Rajat Kapoor',
#  'Graeme Joss',
#  'Molly Ryman',
#  'Fardeen Khan',
#  'Bala',
#  'Chanda Romero',
#  'Akinori Andô',
#  'Robyn Wood',
#  'Hyun-Jung Go',
#  'Zara Dawson',
#  'John Michael Laurin',
#  'Lalit Tiwari',
#  "Q'orianka Kilcher",
#  'Mark Harelik',
#  'Teresa Arbolí',
#  'Stéphane Chivot',
#  'Xiaolin Zhang',
#  'Dan Morgan',
#  'Amanda Donohoe',
#  'Clark Gregg',
#  'Pruitt Taylor Vince',
#  'Bryan Larkin',
#  'Anton Yakovlev',
#  'Mary Lynn Rajskub',
#  'Ante Blind',
#  'Stephan Bieker',
#  'Esmé Bianco',
#  'Henry Max Nelson',
#  'Judith Montgomery',
#  'Briana Evigan',
#  'Michael Patrick Breen',
#  'Cezanne Cuypers',
#  'Danny Huston',
#  'H.M. Wynant',
#  'Frank Gallegos',
#  'Mike Dusi',
#  'Stephanie Kelley',
#  'Ming-Shuai Shih',
#  'Eddie Lee',
#  'Kelly Nyks',
#  'Françoise Kantengwa',
#  'Tomas Spencer',
#  'Vera Pap',
#  'Mikael Hakarauta',
#  'Jeremy London',
#  'Vanessa Carmona',
#  'Anthony S. Johnson',
#  'Frank Harts',
#  'Annie Hibbs',
#  'Kamalinee Mukherjee',
#  'Mary Vidali',
#  'Saoud Al Kaabi',
#  'Harman Baweja',
#  'Talon G. Ackerman',
#  'Sandra Bullock',
#  'György Cserhalmi',
#  'Julie-Marie Parmentier',
#  'Sarah Hassett Jones',
#  'Astrid Overå',
#  'Beverley Eve',
#  'Everette Scott Ortiz',
#  'Paul Gravett',
#  'Michel Voletti',
#  'Helmut Köpping',
#  'Alex Nesic',
#  'Nicolas Besançon',
#  'Amit Shah',
#  'Arthur Peyret',
#  'Chris Messina',
#  'Helen Wilson',
#  'Claudio Santamaria',
#  'Mikaël Gaspar',
#  'David Roper',
#  'Lilia Mendoza',
#  'Paul Chun',
#  'Erica Leerhsen',
#  'Pep Munné',
#  'Selena Haddad',
#  'Shawn Baichoo',
#  'Ashleigh Sumner',
#  'Kirsten Barber',
#  'Mackenzie Mowat',
#  'Jennifer June Ross',
#  'Gareth Macleavy',
#  'Régis Royer',
#  'Lucie Bourdeu',
#  'Amy Matthews',
#  'Portia',
#  'Desmond Harrington',
#  'Aaron Mathias',
#  'Keir Gilchrist',
#  'Axel Prahl',
#  'Ryan Dunn',
#  'Noel Palomaria',
#  'Yisui Zhao',
#  'Gillian Anderson',
#  'James Ramsey',
#  'Clara Conzen',
#  'Muzahid Khan',
#  'Justin Daering',
#  'Gökay Yildiz',
#  'Laura Montana',
#  'Brenda Strong',
#  'Matthias Walter',
#  'Young Hun Choi',
#  'JC Chasez',
#  'Jakob Cedergren',
#  'Peter Anthony Tambakis',
#  'Cécile Laloy',
#  'Paula Chirila',
#  'Geoffrey Arend',
#  'Anne Downie',
#  'Gene Burns',
#  'Luke Dickson',
#  'Christopher Massey',
#  'Laura Donoughue',
#  'Melvil Poupaud',
#  'Dorka Gryllus',
#  'Peter Zizzo',
#  'Ahmed Ahmed',
#  'Mike Cauchon',
#  'Vikas Anand',
#  'Ian McElhinney',
#  'Clement von Franckenstein',
#  'Nick Ferrin',
#  'Eyüp Agilday',
#  'Adam Baldwin',
#  'Dominic Kates',
#  'Gary Cherkassky',
#  'Megumi Ogata',
#  'Brienne De Beau',
#  'Alex Hernandez',
#  'Fayssal Bazzi',
#  'Ward Weemhoff',
#  'Thomas Hedengran',
#  'Monique Chaumette',
#  'Rita Bánczi',
#  'Andrea Di Stefano',
#  'Scott Winters',
#  'Chris Gartin',
#  'Nina Miller',
#  'Minka Kelly',
#  'Lisa Joyce',
#  'Russell M. Haeuser',
#  'Christophe Calmel',
#  'Emilio Gutiérrez Caba',
#  'Toby Marlow',
#  'Ivo Velon',
#  'Naomi Kawase',
#  "Deirdre O'Connell",
#  'Jessica Biel',
#  'Michael Mandell',
#  'Billy Crudup',
#  'Meera Syal',
#  'Roy Black',
#  'Ellie Haddington',
#  'Mike Hinkle',
#  'Rei Dan',
#  'Frankie Faison',
#  'Kerrie Hayes',
#  'Henry Dittman',
#  ...]

# %%
#busca datos actores, lista de los datos de los actores a df y de df a csv
lista_datos_actores_2009_1000_1000 = datos_actores(lista_actores_imdb_2009_1000)
df_datos_actores_2009_1000_1000 = pd.DataFrame(lista_datos_actores_2009_1000_1000)
df_datos_actores_2009_1000_1000.to_csv('lista_actores_2009_1000_1000.csv', index=False)

df_datos_actores_2009_1000_1000
# Out:
# 1. Rachel Bell
# que hace: ['Reparto']
# conocido: ['The Darling Buds of May', '1991–1993 • 16 episodios', 'Priscilla P.', 'Serie de TV', '7,1']
# año: 1950
# premios: Sin oscar
# 2. Bjørn Sundquist
# que hace: ['Reparto', 'Música']
# conocido: ['']
# año: 1948
# premios: Sin Oscar
# 3. Yejin Jeong
# que hace: ['Reparto']
# conocido: ['Una vida nueva']
# año: No data
# premios: Sin oscar
# 4. Chengwei Ren
# que hace: ['Reparto', 'Dirección']
# conocido: ['You ni cai you jia', 'Da Xue Wu Hen', 'Ke ai de Zhong Guo', '7,2']
# año: No data
# premios: Sin Oscar
# 5. Manabu Oshio
# que hace: ['Reparto']
# conocido: ['Yamato nadeshiko', '2000 • 11 episodios', '2005', '2009', '2001 • 11 episodios']
# año: 1978
# premios: Sin oscar
# 6. Lynette Curran
# que hace: ['Reparto']
# conocido: ['']
# año: 1945
# premios: Sin Oscar
# 7. Jhilmil Hazrika
# que hace: ['Reparto']
# conocido: ['Aamir', 'Noi', '5,1']
# año: No data
# premios: Sin oscar
# 8. Uttar Kumar
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1973
# premios: Sin oscar
# 9. Geoff Falk
# que hace: ['Reparto', 'Equipos adicionales']
# conocido: ['']
# año: 1962
# premios: Sin oscar
# 10. Shalim Ortiz
# que hace: ['Reparto', 'Música', 'Producción']
# conocido: ['']
# año: 1979
# premios: Sin Oscar
# 11. Moa Silén
# que hace: ['Reparto']
# conocido: ['Portofino: The Philippines', '6,1', '3,6', '6,6']
# año: 1979
# premios: Sin oscar
# 12. Leon Seidel
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1996
# premios: Sin Oscar
# 13. Xango Henry
# que hace: ['Reparto', 'Especialistas', 'Producción']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 14. Deneb Catalan
# que hace: ['Reparto', 'Producción', 'Cámara y electricidad']
# conocido: ['Death Lotto', 'Serie de TV', 'I Am Your Hairdresser']
# año: No data
# premios: Sin oscar
# 15. David Proval
# que hace: ['Reparto', 'Equipos adicionales']
# conocido: ['']
# año: 1942
# premios: Sin Oscar
# 16. Deb Mukherjee
# que hace: ['Reparto', 'Dirección', 'Producción']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 17. Jason Schwartzman
# que hace: ['Reparto', 'Música', 'Producción']
# conocido: ['']
# año: 1980
# premios: Sin Oscar
# 18. Rhys Thomas
# que hace: ['Reparto', 'Guion', 'Dirección']
# conocido: ['']
# año: 1978
# premios: Nominado a 1 premio BAFTA
# 19. Alejandro de la Madrid
# que hace: ['Reparto']
# conocido: ['']
# año: 1977
# premios: Sin oscar
# 20. Kostas Koronaios
# que hace: ['Reparto', 'Dirección de la segunda unidad o asistencia a dirección']
# conocido: ['Akadimia Platonos', 'Guiness', 'O teleftaios taxitzis', 'Liebestod: Tessereis praxeis', '2007']
# año: No data
# premios: Sin oscar
# 21. Marco Serralta
# que hace: ['Reparto']
# conocido: ['Las californianas', 'La Mission']
# año: No data
# premios: Sin oscar
# 22. Marc Blucas
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1972
# premios: Sin Oscar
# 23. Nicolette Doke
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 24. Kathleen Munroe
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: abril
# premios: Sin Oscar
# 25. Brendan Miller
# que hace: ['Reparto']
# conocido: ['']
# año: 1981
# premios: Sin oscar
# 26. Kestie Morassi
# que hace: ['Reparto', 'Producción']
# conocido: ['']
# año: 1978
# premios: Sin Oscar
# 27. Gary Beadle
# que hace: ['Reparto', 'Guion', 'Banda sonora']
# conocido: ['']
# año: 1965
# premios: Sin Oscar
# 28. Don Hahn
# que hace: ['Producción', 'Dirección', 'Equipos adicionales']
# conocido: ['']
# año: 1955
# premios: Nominado para 2 premios Óscar
# 29. Luke Treadaway
# que hace: ['Reparto', 'Producción', 'Banda sonora']
# conocido: ['']
# año: 1984
# premios: Sin Oscar
# 30. Trevor Richardson
# que hace: ['Reparto', 'Producción', 'Equipo ejecutivo']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 31. Nebojsa Milovanovic
# que hace: ['Reparto']
# conocido: ['Crna svadba', '2021 • 7 episodios', 'Major Dragan KasaninKapetan Dragan Kasanin', 'Serie de TV', '8,6']
# año: 1974
# premios: Sin oscar
# 32. Sofia Vassilieva
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1992
# premios: Sin Oscar
# 33. Juno Temple
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1989
# premios: Nominado para 3 premios Primetime Emmy
# 34. Melia Renee
# que hace: ['Reparto', 'Guion']
# conocido: ['']
# año: 1989
# premios: Sin oscar
# 35. Catherine Dyer
# que hace: ['Reparto', 'Dirección', 'Producción']
# conocido: ['']
# año: noviembre
# premios: Nominado para 1 premio Primetime Emmy
# 36. Francis Renaud
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1967
# premios: Sin Oscar
# 37. Ariel Gade
# que hace: ['Reparto', 'Producción']
# conocido: ['']
# año: 1997
# premios: Sin Oscar
# 38. Eric Allan Kramer
# que hace: ['Reparto', 'Dirección']
# conocido: ['']
# año: 1962
# premios: Sin oscar
# 39. Driss Roukhe
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1968
# premios: Sin Oscar
# 40. Sneha
# que hace: ['Reparto', 'Música', 'Banda sonora']
# conocido: ['']
# año: 1981
# premios: Sin Oscar
# 41. Ric Maddox
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1979
# premios: Sin Oscar
# 42. Marylouise Burke
# que hace: ['Reparto']
# conocido: ['']
# año: 1941
# premios: Sin oscar
# 43. Juli Alexandrov
# que hace: ['Reparto']
# conocido: ['Desperados on the Block']
# año: No data
# premios: Sin oscar
# 44. Jean-Pierre Léaud
# que hace: ['Reparto', 'Dirección de la segunda unidad o asistencia a dirección', 'Dirección']
# conocido: ['']
# año: 1944
# premios: Nominado a 1 premio BAFTA
# 45. Frederick Weller
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1966
# premios: Sin oscar
# 46. Brad Kranich
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 47. Rhonda Aldrich
# que hace: ['Reparto', 'Equipos adicionales']
# conocido: ['Cocodrilo Dundee en Los Angeles', 'Star Trek: La nueva generación', '1988–1991 • 3 episodios', '1985', 'Annie']
# año: No data
# premios: Sin oscar
# 48. Leah Grimsson
# que hace: ['Reparto']
# conocido: ['Metal Man', '2008', '2016', 'Dorris', '2012']
# año: No data
# premios: Sin oscar
# 49. Edica Casanova
# que hace: ['Maquillaje', 'Reparto']
# conocido: ['Fingerprints', '7,1', '8,5', '7,6']
# año: No data
# premios: Sin oscar
# 50. Maria Ribera
# que hace: ['Reparto']
# conocido: ['']
# año: 1978
# premios: Sin Oscar
# 51. Michael Teigen
# que hace: ['Reparto', 'Guion']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 52. October Moore
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 53. Trish Egan
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 54. Jack Kyle
# que hace: ['Reparto', 'Producción']
# conocido: ['']
# año: 1968
# premios: Sin oscar
# 55. Jill K. Allen
# que hace: ['Reparto', 'Efectos visuales']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 56. Zen Ledden
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 57. Paul Calderon
# que hace: ['Reparto', 'Producción', 'Dirección de la segunda unidad o asistencia a dirección']
# conocido: ['']
# año: 1959
# premios: Sin Oscar
# 58. Cheech Marin
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: 1946
# premios: Sin Oscar
# 59. Bettina Engelhardt
# que hace: ['Reparto']
# conocido: ['Unbroken', '2021 • 3 episodios', 'Anette MaxheimerKerstin Ruh', 'Polizistin', 'Serie de TV']
# año: 1971
# premios: Sin oscar
# 60. Nathaniel Brown
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1936
# premios: Sin Oscar
# 61. Alyy Khan
# que hace: ['Reparto']
# conocido: ['']
# año: 1968
# premios: Sin Oscar
# 62. Michael McElhatton
# que hace: ['Reparto', 'Guion']
# conocido: ['']
# año: 1963
# premios: Sin Oscar
# 63. Daphne Khoury
# que hace: ['Reparto', 'Arte', 'Equipos adicionales']
# conocido: ['']
# año: 1979
# premios: Sin oscar
# 64. Kankurô Nakamura
# que hace: ['Reparto']
# conocido: ['Gintama', 'Shinsengumi!', '2004 • 36 episodios', 'Isao Kondo', 'Dôgen(as Kantarô Nakamura)']
# año: 1981
# premios: Sin oscar
# 65. Juan Pablo Arias Barrón
# que hace: ['Dirección', 'Sonido', 'Guion']
# conocido: ['Pumpkinhole', 'Hombre', '2017', 'Dirección']
# año: No data
# premios: Sin oscar
# 66. Lun Zhang
# que hace: ['Reparto', 'Dirección', 'Dirección de la segunda unidad o asistencia a dirección']
# conocido: ['Alima', 'Pu Geng', '1986']
# año: No data
# premios: Sin oscar
# 67. Vienna K. Bradley
# que hace: ['Reparto']
# conocido: ["My Mother's Fairy Tales", '8,7', 'The Pull-Out Method']
# año: No data
# premios: Sin oscar
# 68. Karine Vanasse
# que hace: ['Reparto', 'Producción', 'Banda sonora']
# conocido: ['']
# año: 1983
# premios: Sin Oscar
# 69. Peter Bryant
# que hace: ['Reparto', 'Guion']
# conocido: ['']
# año: 1959
# premios: Sin oscar
# 70. Jere Burns
# que hace: ['Reparto']
# conocido: ['']
# año: 1954
# premios: Sin Oscar
# 71. Alia Rhiana Eckerman
# que hace: ['Reparto', 'Producción', 'Casting']
# conocido: ['']
# año: 1982
# premios: Sin oscar
# 72. Don Wallace
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: febrero
# premios: Sin Oscar
# 73. Paul Garrett
# que hace: ['Reparto']
# conocido: ['Bomba de cereza', 'Revolution', '2012 • 1 episodio', '2009', 'Northman Archer']
# año: No data
# premios: Sin oscar
# 74. Takao Handa
# que hace: ['Reparto']
# conocido: ['Madan Senki Ryûkendô', '2006', '2010', 'Zenzen daijobu']
# año: No data
# premios: Sin oscar
# 75. Suzanne VanDeMark
# que hace: ['Reparto']
# conocido: ['Lonely Joe', 'Somewhere Between Here & There']
# año: No data
# premios: Sin oscar
# 76. Siouzana Melikian
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 77. Frank Howson
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['La burla del destino', 'Friday on My Mind', 'A Thin Life', '4,6']
# año: 1952
# premios: Sin Oscar
# 78. Angelo Custino
# que hace: ['Reparto']
# conocido: ['Otis', 'Mentes criminales', '2007 • 1 episodio', '2009', '2005']
# año: 1991
# premios: Sin oscar
# 79. Kôichi Satô
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['Chûshingura gaiden: Yotsuya kaidan', 'Mibu gishi den', 'Seishun no mon', 'Mishima']
# año: 1960
# premios: Sin Oscar
# 80. Raymond O'Connor
# que hace: ['Reparto']
# conocido: ['']
# año: 1952
# premios: Sin oscar
# 81. Henry David
# que hace: ['Reparto']
# conocido: ['Un plan brillante', 'Evita', 'Los gritos del silencio', 'Sharpe', '2008 • 2 episodios']
# año: 2023
# premios: Sin oscar
# 82. André Barbosa
# que hace: ['Producción', 'Reparto', 'Arte']
# conocido: ['The Resistance', 'One More Day', '2014', '2012', '2000']
# año: No data
# premios: Sin oscar
# 83. Alia Shawkat
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1989
# premios: Sin Oscar
# 84. Emilia Schüle
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1992
# premios: Sin Oscar
# 85. James LaMarr
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['Psychic Experiment', '2:22', 'The Body', 'Producción']
# año: No data
# premios: Sin oscar
# 86. David Svehlík
# que hace: ['Reparto', 'Guion y continuidad']
# conocido: ['']
# año: 1972
# premios: Sin oscar
# 87. Sophie Nyweide
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 88. Jennifer Couch
# que hace: ['Reparto']
# conocido: ['AVH: Alien vs. Hunter', '2007', '2016', 'CU Soon']
# año: No data
# premios: Sin oscar
# 89. Agathe Bonitzer
# que hace: ['Reparto']
# conocido: ['']
# año: 1989
# premios: Sin Oscar
# 90. Scott O'Donnell
# que hace: ['Producción']
# conocido: ['']
# año: No data
# premios: Ganó 1 premio BAFTA
# 91. Antonio Wannek
# que hace: ['Reparto', 'Dirección', 'Edición']
# conocido: ['']
# año: 1979
# premios: Sin Oscar
# 92. Malin Akerman
# que hace: ['Reparto', 'Producción', 'Banda sonora']
# conocido: ['']
# año: 1978
# premios: Sin Oscar
# 93. Elisabeth Röhm
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1973
# premios: Sin Oscar
# 94. Annette Bening
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1958
# premios: Nominado para 4 premios Óscar
# 95. Ekaterina Davydova-Tongur
# que hace: ['Reparto']
# conocido: ['Chudo', 'Domik u reki', 'Vesnoy rastsvetaet lyubov', '2015']
# año: 1986
# premios: Sin oscar
# 96. Ron Perlman
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1950
# premios: Nominado para 2 premios Primetime Emmy
# 97. Monica McShane
# que hace: ['Reparto']
# conocido: ['Guiness', 'The All Together', 'Nicostratos le pélican', 'Dyo meres mono', '2006 • 7 episodios']
# año: No data
# premios: Sin oscar
# 98. Jelena Stupljanin
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: 1978
# premios: Sin Oscar
# 99. Andreína Olivarí
# que hace: ['Reparto']
# conocido: ['La Nana']
# año: No data
# premios: Sin oscar
# 100. Josh Mostel
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1946
# premios: Sin oscar
# 101. Ofer Hayoun
# que hace: ['Reparto', 'Cámara y electricidad']
# conocido: ['']
# año: 1983
# premios: Sin oscar
# 102. Ed Spear
# que hace: ['Sonido', 'Reparto', 'Guion']
# conocido: ['Enter the Void', 'Guidance', "No Man's Land", 'Zero Hour']
# año: 1973
# premios: Sin Oscar
# 103. Marie Black
# que hace: ['Reparto']
# conocido: ['Freedom Park']
# año: No data
# premios: Sin oscar
# 104. Lisa Chung
# que hace: ['Reparto', 'Dirección de la segunda unidad o asistencia a dirección', 'Vestuario']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 105. Marie-Françoise Audollent
# que hace: ['Reparto']
# conocido: ['El código Da Vinci', 'Molière', 'Ma femme me quitte', 'La fille de Prague avec un sac très lourd']
# año: 1943
# premios: Sin oscar
# 106. Til Schweiger
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1963
# premios: Sin Oscar
# 107. Jerome Smith
# que hace: ['Reparto', 'Composición', 'Dirección']
# conocido: ['']
# año: 1992
# premios: Sin oscar
# 108. Eva Mazauric
# que hace: ['Reparto']
# conocido: ['Façade', 'Vainilla y fresa', 'Sauveur Giordano', '2001–2003 • 2 episodios', "Liliane d'AnjouLilianne d'Anjou"]
# año: 1972
# premios: Sin Oscar
# 109. Gloria de Jesús
# que hace: ['Reparto']
# conocido: ['Fantasía ranchera', 'Escuadrón 201', 'Los años han pasado', '5,2']
# año: 1922
# premios: Sin oscar
# 110. Domiziana Cardinali
# que hace: ['Reparto']
# conocido: ['Giulia non esce la sera', 'Il rosso e il blu']
# año: No data
# premios: Sin oscar
# 111. Nicholas Turturro
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1962
# premios: Nominado para 2 premios Primetime Emmy
# 112. Isak Férriz
# que hace: ['Reparto']
# conocido: ['']
# año: 1979
# premios: Sin Oscar
# 113. Kirti Chauhan
# que hace: ['Reparto']
# conocido: ['Aseema: Beyond Boundaries']
# año: No data
# premios: Sin oscar
# 114. Melanie Lynskey
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1977
# premios: Nominado para 3 premios Primetime Emmy
# 115. Eamon Glennon
# que hace: ['Reparto', 'Edición', 'Edición']
# conocido: ['The Black Dawn', 'The Black Dawn', '2009 • 7 episodios', 'Lee', 'Mariposa']
# año: No data
# premios: Sin oscar
# 116. Kamal Sidhu
# que hace: ['Producción', 'Reparto']
# conocido: ['Captain Vyom', '1998 • 1 episodio', '1997', '2009', '2008']
# año: 1971
# premios: Sin oscar
# 117. Ben Shenkman
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1968
# premios: Nominado para 1 premio Primetime Emmy
# 118. Erica Rivas
# que hace: ['Reparto', 'Producción', 'Banda sonora']
# conocido: ['']
# año: 1974
# premios: Sin Oscar
# 119. Matthew Gray Gubler
# que hace: ['Reparto', 'Dirección', 'Producción']
# conocido: ['']
# año: 1980
# premios: Sin Oscar
# 120. Donnie Castillo
# que hace: ['Reparto']
# conocido: ['Ex Cathedra']
# año: No data
# premios: Sin oscar
# 121. Bobb'e J. Thompson
# que hace: ['Reparto', 'Producción']
# conocido: ['']
# año: 1996
# premios: Sin Oscar
# 122. Tetsuji Tamayama
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1980
# premios: Sin Oscar
# 123. Max Watson
# que hace: ['Cámara y electricidad', 'Dirección de fotografía y cámara']
# conocido: ['Eyes of a Roman', 'Waiting']
# año: No data
# premios: Sin oscar
# 124. Ernie Ko
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: 1919
# premios: Ganó 1 premio Primetime Emmy
# 125. David Anzuelo
# que hace: ['Reparto', 'Especialistas', 'Producción']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 126. Virginie Ledoyen
# que hace: ['Reparto', 'Producción', 'Banda sonora']
# conocido: ['']
# año: 1976
# premios: Sin Oscar
# 127. Darwin Barney
# que hace: ['Reparto']
# conocido: ['Calvin Marshall', 'Keep the Faith', '7,6', 'MLB on ESPN', '2017 • 1 episodio']
# año: No data
# premios: Sin oscar
# 128. Chantal Contouri
# que hace: ['Reparto', 'Música']
# conocido: ['']
# año: 1950
# premios: Sin Oscar
# 129. Rich Foran
# que hace: ['Reparto']
# conocido: ["Since I Don't Have You", 'Trapped']
# año: No data
# premios: Sin oscar
# 130. Michael Panes
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1963
# premios: Sin Oscar
# 131. Katrina Walker
# que hace: ['Reparto']
# conocido: ['Breath of Courage', 'To See the Moon in the Morning Sky', 'A Silent Truth', '2012', '2017 • 1 episodio']
# año: No data
# premios: Sin oscar
# 132. Etsushi Toyokawa
# que hace: ['Reparto', 'Dirección']
# conocido: ['']
# año: 1962
# premios: Sin Oscar
# 133. Bárbara Lazón
# que hace: ['Reparto']
# conocido: ['La teta asustada']
# año: No data
# premios: Sin oscar
# 134. Ingrid Nilson
# que hace: ['Reparto', 'Guion', 'Música']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 135. Hugo Silva
# que hace: ['Reparto', 'Dirección', 'Banda sonora']
# conocido: ['']
# año: 1977
# premios: Sin Oscar
# 136. Anastasia Baboussouras
# que hace: ['Reparto']
# conocido: ['Blessed', 'Rush', '2010 • 1 episodio', 'Girl 1']
# año: No data
# premios: Sin oscar
# 137. Sven Nordin
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1957
# premios: Sin Oscar
# 138. Josie Gammell
# que hace: ['Reparto']
# conocido: ['Inocencia interrumpida', 'The Least Among You', 'I Am', 'Thanksgiving']
# año: 1965
# premios: Sin oscar
# 139. Uno Kanda
# que hace: ['Reparto']
# conocido: ['Urutoraman Zeasu', 'Gohatto', 'Ultraman Zearth 2', 'Baby, Baby, Baby!']
# año: 1975
# premios: Sin oscar
# 140. Jean-Paul Girardot
# que hace: ['Reparto']
# conocido: ['Yuki & Nina']
# año: No data
# premios: Sin oscar
# 141. Nicholas Lea
# que hace: ['Reparto', 'Producción', 'Equipos adicionales']
# conocido: ['']
# año: 1962
# premios: Sin Oscar
# 142. David Barlow
# que hace: ['Guion', 'Producción', 'Equipos adicionales']
# conocido: ['Un sexto sentido', '1981–1987 • 43 episodios', 'Guion', 'Serie de TV', '7,7']
# año: No data
# premios: Sin Oscar
# 143. Natalie Slevin
# que hace: ['Reparto']
# conocido: ['House of Boys', 'Unique Sweets', '2013 • 1 episodio']
# año: No data
# premios: Sin oscar
# 144. Sanli Ozlen
# que hace: ['Reparto']
# conocido: ['Patsy', 'My Normal', 'Weapons']
# año: No data
# premios: Sin oscar
# 145. Danny Denzongpa
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: 1948
# premios: Sin Oscar
# 146. Ruth Bradley
# que hace: ['Reparto', 'Música', 'Banda sonora']
# conocido: ['']
# año: 1987
# premios: Sin Oscar
# 147. Alexandre Borges
# que hace: No data
# conocido: No data
# año: No data
# premios: Sin oscar
# 148. Michael Rivera
# que hace: ['Reparto', 'Efectos especiales']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 149. Shu Guang Liang
# que hace: ['Reparto']
# conocido: ['El último bailarín de Mao']
# año: No data
# premios: Sin oscar
# 150. Priyanka Chopra Jonas
# que hace: ['Reparto', 'Producción', 'Música']
# conocido: ['']
# año: 1982
# premios: Sin Oscar
# 151. Jamison Haase
# que hace: ['Reparto']
# conocido: ['']
# año: abril
# premios: Sin oscar
# 152. Steven Brown
# que hace: ['Agente de talentos']
# conocido: No data
# año: No data
# premios: Sin oscar
# 153. Rachael Kemery
# que hace: ['Reparto']
# conocido: ['']
# año: 1984
# premios: Sin oscar
# 154. Maarten Stevenson
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 155. Ben Barnes
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1981
# premios: Sin Oscar
# 156. Natali Broods
# que hace: ['Reparto']
# conocido: ['']
# año: 1976
# premios: Sin Oscar
# 157. Khris Kaneff
# que hace: ['Reparto', 'Arte', 'Equipos adicionales']
# conocido: ["The Devil's Muse", 'Betamax', 'Spreading Darkness', 'Emmanuelle 2000']
# año: 1970
# premios: Sin oscar
# 158. Catarina Wallenstein
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1986
# premios: Sin Oscar
# 159. Sergey Chonishvili
# que hace: ['Reparto']
# conocido: ['Azazel', '2002 • 3 episodios', '7,8', '6,3']
# año: 1965
# premios: Sin oscar
# 160. Marcio Vito
# que hace: ['Reparto', 'Equipos adicionales', 'Dirección de la segunda unidad o asistencia a dirección']
# conocido: ['5x Favela, Agora por Nós Mesmos', 'Para Sempre Nunca Mais', 'Machado do Brasil', 'Xuxa e os Duendes']
# año: 1972
# premios: Sin Oscar
# 161. Peggy Lukac
# que hace: ['Reparto']
# conocido: ['']
# año: 1949
# premios: Sin oscar
# 162. Samantha Morton
# que hace: ['Reparto', 'Guion', 'Dirección']
# conocido: ['']
# año: 1977
# premios: Nominado para 2 premios Óscar
# 163. Sammy Sheik
# que hace: ['Reparto', 'Composición', 'Equipos adicionales']
# conocido: ['']
# año: 1981
# premios: Sin Oscar
# 164. Lucy McMichael
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 165. Caseyarnoux Charlot
# que hace: ['Reparto']
# conocido: ['The Exploding Girl']
# año: No data
# premios: Sin oscar
# 166. Jesse Tyler Ferguson
# que hace: ['Reparto', 'Producción', 'Banda sonora']
# conocido: ['']
# año: 1975
# premios: Nominado para 5 premios Primetime Emmy
# 167. Colleen Camp
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1953
# premios: Sin Oscar
# 168. Amitabh Srivastava
# que hace: ['Reparto', 'Guion']
# conocido: ['Kai po che!', 'Aalavandhan', 'Hey Ram', 'Road, Movie']
# año: No data
# premios: Sin oscar
# 169. Jon Kabira
# que hace: ['Reparto']
# conocido: ['Suki na hito ga iru koto', '2016 • 1 episodio', 'Reparto', 'Reparto', 'Soichiro Asami']
# año: No data
# premios: Sin oscar
# 170. Brennan Brown
# que hace: ['Reparto', 'Equipos adicionales']
# conocido: ['']
# año: 1968
# premios: Sin oscar
# 171. Kevin Indio Copeland
# que hace: ['Reparto', 'Especialistas', 'Música']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 172. Rula Blanco
# que hace: ['Reparto']
# conocido: ['Agallas']
# año: No data
# premios: Sin oscar
# 173. Michele Matheson
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1971
# premios: Sin oscar
# 174. Salli Richardson-Whitfield
# que hace: ['Reparto', 'Dirección', 'Producción']
# conocido: ['']
# año: 1967
# premios: Sin Oscar
# 175. Arne Boysen
# que hace: ['Reparto']
# conocido: ['Atletu']
# año: No data
# premios: Sin oscar
# 176. Gordon Currie
# que hace: ['Reparto', 'Dirección', 'Producción']
# conocido: ['']
# año: 1965
# premios: Sin Oscar
# 177. Parikshit Sahni
# que hace: ['Reparto', 'Dirección', 'Producción']
# conocido: ['']
# año: 1944
# premios: Sin oscar
# 178. Bruno Blairet
# que hace: ['Reparto']
# conocido: ['Espion(s)', 'La mujer más asesinada del mundo', 'Un coeur simple', 'À coeur ouvert']
# año: No data
# premios: Sin oscar
# 179. John Lasseter
# que hace: ['Producción', 'Guion', 'Dirección']
# conocido: ['']
# año: 1957
# premios: Ganó 1 premio Óscar
# 180. Aarti Chhabria
# que hace: ['Reparto', 'Dirección', 'Producción']
# conocido: ['']
# año: 1982
# premios: Sin Oscar
# 181. Ken Clark
# que hace: ['Reparto']
# conocido: ['']
# año: 1927
# premios: Sin oscar
# 182. Lauren Weedman
# que hace: ['Reparto', 'Guion']
# conocido: ['']
# año: 1969
# premios: Sin Oscar
# 183. Al Roker
# que hace: ['Producción', 'Reparto', 'Guion']
# conocido: ['']
# año: 1954
# premios: Sin Oscar
# 184. Adán Rodríguez
# que hace: ['Equipos adicionales', 'Dirección', 'Dirección de fotografía y cámara']
# conocido: ['As I Live and Breathe', 'The Comfort of Home', 'All That Matters', 'Wasted Space']
# año: No data
# premios: Sin oscar
# 185. Roselyn Sanchez
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1973
# premios: Sin Oscar
# 186. Michael Graziadei
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1979
# premios: Sin Oscar
# 187. Pooja Bhatt
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1972
# premios: Sin Oscar
# 188. Kali Rocha
# que hace: ['Reparto', 'Guion']
# conocido: ['']
# año: 1971
# premios: Sin oscar
# 189. Peter Demelo
# que hace: ['Reparto']
# conocido: ['Bombay Summer']
# año: No data
# premios: Sin oscar
# 190. Guillermo Villegas
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 191. Catherine Bruhier
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: mayo
# premios: Sin Oscar
# 192. Romana Abercromby
# que hace: ['Reparto']
# conocido: ['Lip Service', '2010 • 2 episodios', '2009', 'Dee Robison', 'Sarah']
# año: No data
# premios: Sin oscar
# 193. Jean Reno
# que hace: ['Reparto']
# conocido: ['']
# año: 1948
# premios: Sin Oscar
# 194. Marc Oliver Mögling
# que hace: ['Reparto']
# conocido: ['Spielzeugland Endstation', 'Frischfilm']
# año: No data
# premios: Sin oscar
# 195. Tom Cameron
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 196. Rodolphe Pauly
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1979
# premios: Sin Oscar
# 197. John Hambrick
# que hace: ['Reparto']
# conocido: ['Wonderful World', 'Teléfono', 'Fabricando al hombre perfecto', 'Homeland Nation: Mescalero Apache']
# año: 1940
# premios: Sin Oscar
# 198. Cheng-yang Wang
# que hace: ['Reparto']
# conocido: ['Nan sheng jia li xin zhuan', '6,4', '7,9', 'Song Yaoru fuqin']
# año: No data
# premios: Sin Oscar
# 199. Lucy Adden
# que hace: ['Reparto', 'Dirección de la segunda unidad o asistencia a dirección']
# conocido: ['Redland', 'The Franklin Abraham', 'Meet Market', 'The Martyrdom of St Agnes']
# año: No data
# premios: Sin oscar
# 200. Gyton Grantley
# que hace: ['Reparto']
# conocido: ['']
# año: 1980
# premios: Sin Oscar
# 201. Dominique Vandenberg
# que hace: ['Reparto', 'Especialistas', 'Producción']
# conocido: ['']
# año: 1969
# premios: Sin oscar
# 202. Andrea Reimer
# que hace: ['Reparto']
# conocido: ['SuperBrother']
# año: No data
# premios: Sin oscar
# 203. Bevin Hamilton
# que hace: ['Reparto', 'Música', 'Dirección']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 204. Antonino Bruschetta
# que hace: ['Reparto', 'Guion', 'Dirección']
# conocido: ['']
# año: 1962
# premios: Sin Oscar
# 205. Teri Hatcher
# que hace: ['Reparto', 'Guion', 'Dirección']
# conocido: ['']
# año: 1964
# premios: Nominado para 1 premio Primetime Emmy
# 206. Bernie Hodges
# que hace: ['Reparto', 'Producción', 'Dirección de casting']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 207. Ethel Rojo
# que hace: ['Reparto']
# conocido: ['']
# año: 1937
# premios: Sin oscar
# 208. Pepa Pedroche
# que hace: ['Reparto', 'Equipos adicionales', 'Dirección de la segunda unidad o asistencia a dirección']
# conocido: ['El laberinto del fauno', 'Amar es para siempre', '2008–2010 • 269 episodios', '2000', '1999']
# año: 1967
# premios: Sin Oscar
# 209. Mikel Sarah Lambert
# que hace: ['Reparto']
# conocido: ['El secreto de Thomas Crown', 'Frank the Rat', 'Queenie in Love', 'Los mejores deseos']
# año: No data
# premios: Sin oscar
# 210. Glória Pires
# que hace: ['Reparto', 'Guion', 'Música']
# conocido: ['']
# año: 1963
# premios: Sin Oscar
# 211. Kerris Dorsey
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1998
# premios: Sin Oscar
# 212. Alex Scott
# que hace: ['Reparto']
# conocido: ['']
# año: 1929
# premios: Sin oscar
# 213. Kerri Hellmuth
# que hace: ['Reparto', 'Diseño de vestuario', 'Guion']
# conocido: ['The Black Dawn', 'The Black Dawn', '2009 • 7 episodios', 'Elyse', 'Abigail']
# año: No data
# premios: Sin oscar
# 214. Alwara Höfels
# que hace: ['Reparto']
# conocido: ['']
# año: 1982
# premios: Sin Oscar
# 215. Danielle Garavaglia
# que hace: ['Reparto']
# conocido: ['Once & For All']
# año: No data
# premios: Sin oscar
# 216. Alexander Held
# que hace: ['Reparto']
# conocido: ['El hundimiento', 'Sophie Scholl (Los últimos días)', 'RAF Facción del ejército rojo', 'La ola']
# año: 1958
# premios: Sin Oscar
# 217. Laurent Capelluto
# que hace: ['Reparto']
# conocido: ['']
# año: 1971
# premios: Sin Oscar
# 218. Yancey Arias
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: junio
# premios: Sin Oscar
# 219. Yvan Attal
# que hace: ['Reparto', 'Guion', 'Dirección']
# conocido: ['']
# año: 1965
# premios: Sin Oscar
# 220. Fouad Habash
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 221. Alex van Warmerdam
# que hace: ['Reparto', 'Guion', 'Dirección']
# conocido: ['']
# año: 1952
# premios: Sin Oscar
# 222. Marc Zwinz
# que hace: ['Reparto', 'Guion']
# conocido: ['']
# año: 1974
# premios: Sin oscar
# 223. Mirela Naska
# que hace: ['Reparto']
# conocido: ['Filma te shkurter 2010/2', '2010', '2018', '2015', '2011']
# año: No data
# premios: Sin oscar
# 224. Aasif Mandvi
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1966
# premios: Sin Oscar
# 225. Mattia Zaccaro
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 226. Marcelo Armand
# que hace: ['Reparto']
# conocido: ['Boogie, el aceitoso', 'Warcraft III: Reforged', '2020', '2012', '2016']
# año: No data
# premios: Sin oscar
# 227. Petar Sekulic
# que hace: ['Sonido']
# conocido: ['Biti covek: Ivo Andric', '2015 • 4 episodios']
# año: No data
# premios: Sin oscar
# 228. Isabella Rossellini
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1952
# premios: Nominado para 1 premio Primetime Emmy
# 229. Ekin Cheng
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1967
# premios: Sin Oscar
# 230. Carson Grant
# que hace: ['Reparto', 'Producción', 'Guion y continuidad']
# conocido: ['']
# año: 1950
# premios: Sin Oscar
# 231. Stephen Root
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1951
# premios: Nominado para 1 premio Primetime Emmy
# 232. Laurent Larrieu
# que hace: ['Especialistas', 'Reparto', 'Equipos adicionales']
# conocido: ['Micmacs', 'Humans', 'Dante 01', 'Fair Play']
# año: 1969
# premios: Sin oscar
# 233. Lauren Gleason
# que hace: ['Equipos adicionales', 'Producción']
# conocido: ['FBI', '2021–2023 • 12 episodios', 'Equipos adicionales', 'Serie de TV', '8,1']
# año: No data
# premios: Sin oscar
# 234. Kristin Chenoweth
# que hace: ['Reparto', 'Producción', 'Equipos adicionales']
# conocido: ['']
# año: 1968
# premios: Ganó 1 premio Primetime Emmy
# 235. Eriko Satô
# que hace: ['Reparto', 'Música']
# conocido: ['Funuke domo, kanashimi no ai wo misero', 'Kyûtî Hanî', 'El hundimiento de Japón', 'Nanase futatabi']
# año: 1981
# premios: Sin Oscar
# 236. Kim Hye-ja
# que hace: ['Reparto']
# conocido: ['']
# año: 1941
# premios: Sin Oscar
# 237. Paul Kelly
# que hace: ['Reparto', 'Guion', 'Banda sonora']
# conocido: ['']
# año: 1899
# premios: Sin oscar
# 238. Michael Becht
# que hace: ['Reparto']
# conocido: ['A Kiss of Chaos']
# año: No data
# premios: Sin oscar
# 239. Antti Reini
# que hace: ['Reparto', 'Equipos adicionales', 'Dirección']
# conocido: ['']
# año: 1964
# premios: Sin oscar
# 240. Michael Showers
# que hace: ['Reparto']
# conocido: ['Philip Morris ¡Te quiero!', 'Tekken', 'Traffic', 'Colombiana']
# año: 1966
# premios: Sin Oscar
# 241. Jose Candelario
# que hace: ['Guion', 'Cámara y electricidad']
# conocido: ['Objects of Time']
# año: No data
# premios: Sin oscar
# 242. Iza Calzado
# que hace: ['Reparto', 'Producción']
# conocido: ['']
# año: 1982
# premios: Sin Oscar
# 243. François Marthouret
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1943
# premios: Sin oscar
# 244. Maynor Alvarado
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 245. Jamie Foxx
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1967
# premios: Ganó 1 premio Óscar
# 246. Kirsten Berman
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['Million Dollar Baby', 'Hot Tamale (Al rojo vivo)', 'Step One Breathe', '2,0']
# año: No data
# premios: Sin oscar
# 247. André Hennicke
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: 1958
# premios: Sin Oscar
# 248. Carolina Bonetti
# que hace: ['Reparto', 'Equipos adicionales', 'Guion']
# conocido: ['El asesino', 'I Am Echo', 'Donde Hubo Fuego', '2022 • 12 episodios', 'Maid']
# año: 1985
# premios: Sin oscar
# 249. Latichia Brown
# que hace: ['Reparto']
# conocido: ['The First Breath of Tengan Rei']
# año: No data
# premios: Sin oscar
# 250. Kate Arrington
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 251. Bujar Lako
# que hace: ['Reparto']
# conocido: ['Syri magjik', 'Gjeneral gramafoni', 'Përballimi', 'Ballë për ballë']
# año: 1947
# premios: Sin Oscar
# 252. Christo Jivkov
# que hace: ['Reparto', 'Producción', 'Dirección de la segunda unidad o asistencia a dirección']
# conocido: ['']
# año: 1975
# premios: Sin Oscar
# 253. Rosa Isabel Lorenzo
# que hace: ['Reparto']
# conocido: ['Chance', 'Manos de Piedra', 'Causa Justa', "Teta 'pa los manes"]
# año: No data
# premios: Sin oscar
# 254. Greg Timmermans
# que hace: ['Reparto']
# conocido: ['']
# año: 1979
# premios: Sin oscar
# 255. Kieran Culkin
# que hace: ['Reparto']
# conocido: ['']
# año: 1982
# premios: Nominado para 3 premios Primetime Emmy
# 256. Moisés Acevedo
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 257. Perla Bautista
# que hace: ['Reparto']
# conocido: ['']
# año: 1940
# premios: Sin Oscar
# 258. Eva Birthistle
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1974
# premios: Sin Oscar
# 259. Alberta Watson
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1955
# premios: Sin Oscar
# 260. Mikijirô Hira
# que hace: ['Reparto']
# conocido: ['']
# año: 1933
# premios: Sin Oscar
# 261. Saurabh Shukla
# que hace: ['Reparto', 'Guion', 'Dirección']
# conocido: ['']
# año: 1963
# premios: Sin Oscar
# 262. Kristanna Loken
# que hace: ['Reparto', 'Producción', 'Equipo ejecutivo']
# conocido: ['']
# año: 1979
# premios: Sin Oscar
# 263. Katrin Sass
# que hace: ['Reparto']
# conocido: ['']
# año: 1956
# premios: Sin Oscar
# 264. Tom Mannion
# que hace: ['Reparto']
# conocido: ['El retorno del jedi', 'Centurión', 'Beyond the Sea', 'Crupier']
# año: No data
# premios: Sin oscar
# 265. Parris Biggs
# que hace: ['Reparto']
# conocido: ['Family Business']
# año: No data
# premios: Sin oscar
# 266. Bryony Seth
# que hace: ['Reparto']
# conocido: ['Hollyoaks: In the City', '2006 • 18 episodios', 'Lol', '2008–2010 • 15 episodios', '2009']
# año: No data
# premios: Sin oscar
# 267. Milka Ahlroth
# que hace: ['Reparto', 'Diseño de vestuario']
# conocido: ['']
# año: 1966
# premios: Sin Oscar
# 268. Alexandru Potocean
# que hace: ['Reparto']
# conocido: ['']
# año: 1984
# premios: Sin Oscar
# 269. Thekla Reuten
# que hace: ['Reparto', 'Producción']
# conocido: ['']
# año: 1975
# premios: Sin Oscar
# 270. Sandra Alves
# que hace: ['Dirección', 'Edición', 'Dirección de fotografía y cámara']
# conocido: ['Seas of the Banished', 'Dirección', '2014']
# año: No data
# premios: Sin oscar
# 271. Jeremy Sumpter
# que hace: ['Reparto', 'Producción', 'Cámara y electricidad']
# conocido: ['']
# año: 1989
# premios: Sin Oscar
# 272. Thomas Lennon
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1970
# premios: Nominado para 3 premios Primetime Emmy
# 273. Paul Hogan
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: 1939
# premios: Nominado para 1 premio Óscar
# 274. Tyrone LaForrest
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['Against the Grain', 'Shades of Julia', 'El abogado', '2004 • 1 episodio', '2009']
# año: No data
# premios: Sin oscar
# 275. Amanda Fuller
# que hace: ['Reparto', 'Dirección', 'Producción']
# conocido: ['']
# año: 1984
# premios: Sin Oscar
# 276. Heinz-Josef Braun
# que hace: ['Reparto', 'Música']
# conocido: ['Aeon - Countdown im All', '2000 • 3 episodios', 'Karli Spitz', 'Serie de TV', '6,4']
# año: 1957
# premios: Sin oscar
# 277. Shazia Pascal
# que hace: ['Reparto', 'Banda sonora', 'Equipo ejecutivo']
# conocido: ['']
# año: julio
# premios: Sin oscar
# 278. Pat Fisher
# que hace: ['Equipos adicionales']
# conocido: ['Motörhead: Clean Your Clock']
# año: No data
# premios: Sin oscar
# 279. Collette Wolfe
# que hace: ['Reparto']
# conocido: ['']
# año: 1980
# premios: Sin oscar
# 280. Grete Havnesköld
# que hace: ['Reparto']
# conocido: ['']
# año: 1986
# premios: Sin oscar
# 281. József Varga
# que hace: ['Reparto']
# conocido: ['Álljon meg a menet!', 'Partea ta de vina', 'Castelanii']
# año: 1902
# premios: Sin oscar
# 282. Tony Devon
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1951
# premios: Sin Oscar
# 283. Rahul Dev
# que hace: ['Reparto']
# conocido: ['']
# año: 1968
# premios: Sin Oscar
# 284. Madeleine Greaves
# que hace: ['Reparto']
# conocido: ['Donde viven los monstruos', 'Blue Heelers', '2002 • 1 episodio', '2007']
# año: No data
# premios: Sin oscar
# 285. Franziska Weisz
# que hace: ['Reparto']
# conocido: ['']
# año: 1980
# premios: Sin Oscar
# 286. Pia Röver
# que hace: ['Reparto']
# conocido: ['Feuchtgebiete', 'Mondscheinsonate', 'Gemelas', 'Human Kapital']
# año: No data
# premios: Sin oscar
# 287. Thomas Frere
# que hace: ['Reparto']
# conocido: ['The Spell', 'Coronation Street', '2022 • 3 episodios', 'Vicar', 'Serie de TV']
# año: No data
# premios: Sin oscar
# 288. Kenneth Welsh
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1942
# premios: Sin Oscar
# 289. Ving Rhames
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1959
# premios: Nominado para 1 premio Primetime Emmy
# 290. Michelle Belegrin
# que hace: No data
# conocido: No data
# año: No data
# premios: Sin oscar
# 291. Louis Mustillo
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1958
# premios: Sin oscar
# 292. Devin DiGonno
# que hace: ['Producción', 'Equipos adicionales', 'Reparto']
# conocido: ['']
# año: 1969
# premios: Sin Oscar
# 293. Murli Sharma
# que hace: ['Reparto']
# conocido: ['']
# año: 1972
# premios: Sin Oscar
# 294. Ann Perry Wallace
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 295. Peter Franzén
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1971
# premios: Sin Oscar
# 296. Spyros Fokas
# que hace: No data
# conocido: No data
# año: No data
# premios: Sin oscar
# 297. Adam Gregory
# que hace: ['Reparto', 'Dirección de fotografía y cámara', 'Producción']
# conocido: ['']
# año: 1987
# premios: Sin Oscar
# 298. Hans Petter Hansen
# que hace: ['Reparto', 'Equipos adicionales', 'Banda sonora']
# conocido: ['Pyromanen', 'Pan', 'Jernanger', 'Melodi grand prix']
# año: No data
# premios: Sin oscar
# 299. Josh Pais
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: junio
# premios: Sin Oscar
# 300. Sam Murphy
# que hace: ['Reparto', 'Dirección']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 301. Anatole Taubman
# que hace: ['Reparto', 'Producción']
# conocido: ['']
# año: 1970
# premios: Sin Oscar
# 302. Jun Kunimura
# que hace: ['Reparto']
# conocido: ['']
# año: 1955
# premios: Sin Oscar
# 303. Silvio Pollio
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['How It All Went Down', 'Shut Up and Shoot!', '¡Viven!', 'Guido Superstar: The Rise of Guido']
# año: 1972
# premios: Sin Oscar
# 304. Armin Mueller-Stahl
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1930
# premios: Nominado para 1 premio Óscar
# 305. Xochiti Guzman
# que hace: ['Reparto']
# conocido: ['La Mission']
# año: No data
# premios: Sin oscar
# 306. Frank Vincent
# que hace: ['Reparto', 'Producción', 'Equipos adicionales']
# conocido: ['']
# año: 1937
# premios: Sin Oscar
# 307. Beyoncé
# que hace: ['Music Artist', 'Reparto', 'Música']
# conocido: ['']
# año: 1981
# premios: Nominado para 1 premio Óscar
# 308. Orhan Whyte
# que hace: ['Reparto']
# conocido: ['1 Day']
# año: No data
# premios: Sin oscar
# 309. Gerry Mendicino
# que hace: ['Reparto', 'Efectos visuales']
# conocido: ['']
# año: 1950
# premios: Sin oscar
# 310. Sheung-ching Lee
# que hace: ['Reparto', 'Guion']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 311. Werner De Smedt
# que hace: ['Reparto']
# conocido: ['']
# año: 1970
# premios: Sin oscar
# 312. Helena Vierikko
# que hace: ['Reparto', 'Equipos adicionales']
# conocido: ['Kissan kuolema', 'Porttikielto taivaaseen', 'Kaksipäisen kotkan varjossa', 'Munkkivuori', '2022 • 10 episodios']
# año: 1980
# premios: Sin Oscar
# 313. Mo Byrnes
# que hace: ['Reparto']
# conocido: ['The Red Machine']
# año: No data
# premios: Sin Oscar
# 314. Paige Cooper
# que hace: ['Reparto']
# conocido: ['Notes']
# año: No data
# premios: Sin oscar
# 315. Rusty Schwimmer
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: agosto
# premios: Sin Oscar
# 316. Isaiah Bobo
# que hace: ['Reparto']
# conocido: ['The Mountain, the River and the Road']
# año: No data
# premios: Sin oscar
# 317. George Russo
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 318. Neri Marcorè
# que hace: ['Reparto', 'Equipos adicionales', 'Dirección']
# conocido: ['']
# año: 1966
# premios: Sin Oscar
# 319. Michael Farris
# que hace: ['Guion', 'Producción']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 320. Rosemary De Angelis
# que hace: ['Reparto']
# conocido: ['']
# año: 1933
# premios: Sin oscar
# 321. Gord Rand
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 322. Masaya Kikawada
# que hace: ['Reparto']
# conocido: ['Bishôjo Senshi Sailor Moon', '2003–2004 • 20 episodios', '2007', '2003', '2005']
# año: 1980
# premios: Sin oscar
# 323. Esmond Chung
# que hace: ['Reparto']
# conocido: ['50 primeras citas', 'Magnum, P.I.', '1981–1988 • 8 episodios', "Dr. Chad 'Ewalu", 'Kauai Cop']
# año: No data
# premios: Sin oscar
# 324. James Wilby
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1958
# premios: Sin Oscar
# 325. Vanessa Streiff
# que hace: ['Reparto']
# conocido: ['New York Lately']
# año: No data
# premios: Sin oscar
# 326. Peter Haber
# que hace: ['Reparto', 'Producción', 'Banda sonora']
# conocido: ['']
# año: 1952
# premios: Sin Oscar
# 327. Letícia Tavares
# que hace: ['Reparto', 'Equipos adicionales']
# conocido: ['No Meu Lugar', 'Balada na Calada', 'OCD']
# año: No data
# premios: Sin oscar
# 328. Jasen Swafford
# que hace: ['Reparto']
# conocido: ['Little Black Dress', 'Misterios sin resolver', '1996 • 1 episodio', '2009']
# año: 1972
# premios: Sin oscar
# 329. John Gleeson Connolly
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 330. Fazeng Guo
# que hace: ['Reparto']
# conocido: ['Te gao ke zai xing dong', 'Chief Zhang', 'Reparto', '1999']
# año: No data
# premios: Sin Oscar
# 331. Amy Rogers
# que hace: ['Reparto']
# conocido: ['Evil', '2019 • 1 episodio']
# año: No data
# premios: Sin oscar
# 332. Braxton Davis
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1969
# premios: Sin Oscar
# 333. Misty Madden
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['The Black Dawn', 'The Black Dawn', '2009 • 7 episodios', 'Julie', 'Corto']
# año: No data
# premios: Sin oscar
# 334. Jess Weixler
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: junio
# premios: Sin Oscar
# 335. Patricia Belcher
# que hace: ['Reparto', 'Producción', 'Banda sonora']
# conocido: ['']
# año: 1954
# premios: Sin Oscar
# 336. King Jeter
# que hace: ['Reparto']
# conocido: ['The Genesis Project', '8,2']
# año: No data
# premios: Sin oscar
# 337. Justin Bradley
# que hace: ['Reparto', 'Guion']
# conocido: ['El corazón de la bestia', 'El club de medianoche', '1999 • 1 episodio', '2001', '2009']
# año: 1985
# premios: Sin oscar
# 338. Marc D. Donovan
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 339. Paul Schneider
# que hace: ['Reparto', 'Guion', 'Dirección']
# conocido: ['']
# año: 1976
# premios: Sin Oscar
# 340. C.R. Simha
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['Ashwamedha', 'Dirección', '1983', '2010']
# año: 2014
# premios: Sin oscar
# 341. Alvin Addo-Quaye
# que hace: ['Reparto']
# conocido: ['The Butterfly Tattoo', 'Coronation Street', '2023 • 1 episodio', '2011']
# año: No data
# premios: Sin oscar
# 342. Do-rim Choi
# que hace: ['Reparto']
# conocido: ['Jal al-ji-do mot-ha-myeon-seo']
# año: No data
# premios: Sin oscar
# 343. Wendy Playfair
# que hace: ['Reparto']
# conocido: ['Accidents Happen', 'Ride a Wild Pony', 'Spirited', '2010 • 1 episodio', 'Minnie Donovan']
# año: 1926
# premios: Sin oscar
# 344. Karoline Herfurth
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1984
# premios: Sin Oscar
# 345. Zack Bennett
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1988
# premios: Sin Oscar
# 346. Delillo Gary
# que hace: ['Reparto']
# conocido: ['Hangar Rats']
# año: No data
# premios: Sin oscar
# 347. Gino Cafarelli
# que hace: ['Reparto', 'Producción', 'Dirección de casting']
# conocido: ['']
# año: 1969
# premios: Sin Oscar
# 348. Christopher Lambert
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1957
# premios: Sin Oscar
# 349. Marcia Gay Harden
# que hace: ['Reparto', 'Producción']
# conocido: ['']
# año: 1959
# premios: Ganó 1 premio Óscar
# 350. Ervin Nagy
# que hace: ['Reparto', 'Producción']
# conocido: ['Nincsen nekem vágyam semmi', 'Comrade Drakulich', 'Mélyen örzött titkok', 'En cuerpo y alma']
# año: 1976
# premios: Sin Oscar
# 351. Rossana Camhi
# que hace: ['Reparto']
# conocido: ['La última y nos vamos']
# año: No data
# premios: Sin oscar
# 352. Efe Toptan
# que hace: ['Reparto']
# conocido: ['Oturak Imparatoru Recep']
# año: No data
# premios: Sin oscar
# 353. Freya Parks
# que hace: ['Reparto']
# conocido: ['']
# año: noviembre
# premios: Sin oscar
# 354. Cosmo Pfeil
# que hace: ['Reparto', 'Dirección de la segunda unidad o asistencia a dirección', 'Dirección']
# conocido: ['Take Shelter', 'Acceptable Limits', 'Serie de TV', '7,1']
# año: 1977
# premios: Sin oscar
# 355. Stephen Lang
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1952
# premios: Sin Oscar
# 356. Allyson Muñoz
# que hace: ['Reparto']
# conocido: ['Abriendo juego (Choque y fuga)', 'The Gallery', 'La mujer de tierra']
# año: No data
# premios: Sin oscar
# 357. Rakhi Sawant
# que hace: ['Reparto', 'Dirección', 'Maquillaje']
# conocido: ['']
# año: 1978
# premios: Sin oscar
# 358. Manoj K. Jayan
# que hace: ['Reparto', 'Música', 'Dirección']
# conocido: ['']
# año: 1966
# premios: Sin Oscar
# 359. Peter Easterbrook
# que hace: ['Reparto']
# conocido: ['The Butterfly Tattoo', 'The Turing Enigma']
# año: No data
# premios: Sin oscar
# 360. Rie Rasmussen
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1976
# premios: Sin Oscar
# 361. Peter Kurth
# que hace: ['Reparto']
# conocido: ['']
# año: 1957
# premios: Sin Oscar
# 362. Natasa Janjic Medancic
# que hace: ['Reparto']
# conocido: ['']
# año: 1981
# premios: Sin Oscar
# 363. Curtis Grafton
# que hace: ['Reparto']
# conocido: ['A Line in the Sand']
# año: No data
# premios: Sin oscar
# 364. Christopher Cass
# que hace: ['Reparto', 'Dirección', 'Producción']
# conocido: ['Trey Pops', 'Scrubbers', 'The Bus Stop', 'Interrupted Girls']
# año: 1958
# premios: Sin Oscar
# 365. Leo Anderson Akana
# que hace: ['Reparto', 'Guion']
# conocido: ["La princesa Ka'iulani", 'Kumu Hina']
# año: No data
# premios: Sin oscar
# 366. James Fox
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1939
# premios: Ganó 1 premio BAFTA
# 367. Eric Woolfe
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 368. Geneviève Mnich
# que hace: ['Reparto']
# conocido: ['Le chevalier de Pardaillan', '1988', 'Christine', 'Película de TV', '7,6']
# año: 1942
# premios: Sin oscar
# 369. James L. Ward
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 370. Elizabeth Marvel
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1969
# premios: Sin Oscar
# 371. Loïc Peckels
# que hace: ['Reparto']
# conocido: ['House of Boys', 'Perl oder Pica']
# año: No data
# premios: Sin oscar
# 372. Reese Alexander
# que hace: ['Reparto', 'Transporte', 'Especialistas']
# conocido: ['']
# año: marzo
# premios: Sin oscar
# 373. Hilal Kaboub
# que hace: ['Reparto']
# conocido: ['Fauda', '2015 • 2 episodios', 'Security Guard Two(as Hillal Kabub)', 'Serie de TV', '7,1']
# año: 1975
# premios: Sin oscar
# 374. Jason Britt
# que hace: ['Reparto', 'Especialistas']
# conocido: ['Decisions', 'Parts & Labor', 'Semper Ride', 'Serie de TV']
# año: No data
# premios: Sin Oscar
# 375. Valentina Vargas
# que hace: ['Reparto']
# conocido: ['']
# año: 1964
# premios: Sin oscar
# 376. Sara Raftery
# que hace: ['Reparto', 'Equipos adicionales']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 377. Diana Gómez
# que hace: ['Reparto']
# conocido: ['']
# año: 1989
# premios: Sin oscar
# 378. Bimba Bosé
# que hace: ['Reparto', 'Maquillaje', 'Banda sonora']
# conocido: ['']
# año: 1975
# premios: Sin oscar
# 379. Connor Joss
# que hace: ['Reparto']
# conocido: ['The Clan']
# año: No data
# premios: Sin oscar
# 380. Stephanie Marois
# que hace: ['Reparto']
# conocido: ['Smallville', '2008 • 1 episodio', '2009', 'Lena', 'Serie de TV']
# año: No data
# premios: Sin oscar
# 381. Nobu Imai
# que hace: ['Equipos adicionales', 'Reparto', 'Localización']
# conocido: ['Enter the Void', 'Cerezos en flor', 'Heroes and Villains', '2008 • 1 episodio']
# año: No data
# premios: Sin oscar
# 382. Lee Shin
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 383. Andrei Aradits
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 384. Joanne Whalley
# que hace: ['Reparto']
# conocido: ['']
# año: 1961
# premios: Nominado a 1 premio BAFTA
# 385. Vladimir Rajcic
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1974
# premios: Sin oscar
# 386. Kevin Isola
# que hace: ['Reparto', 'Guion']
# conocido: ['']
# año: enero
# premios: Sin oscar
# 387. Sandy Walsh
# que hace: ['Reparto']
# conocido: ['Emmerdale', '2003 • 52 episodios', 'Peep Show', '2003 • 2 episodios', 'Trish']
# año: No data
# premios: Sin oscar
# 388. John Filmanowicz
# que hace: ['Reparto', 'Cámara y electricidad', 'Equipos adicionales']
# conocido: ['Baraboo', 'Bob Esponja', '2020 • 1 episodio', '2003', '2023']
# año: No data
# premios: Sin oscar
# 389. Zeca Cenovicz
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 390. Mélanie Doutey
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1978
# premios: Sin Oscar
# 391. Won Bin
# que hace: ['Reparto']
# conocido: ['']
# año: 1977
# ...
# año: 1998
# premios: Sin Oscar
# 894. Sandra Bullock
# que hace: ['Producción', 'Reparto', 'Música']
# conocido: ['']
# año: 1964
# premios: Ganó 1 premio Óscar
# 895. György Cserhalmi
# que hace: ['Reparto']
# conocido: ['']
# año: 1948
# premios: Sin Oscar
# 896. Julie-Marie Parmentier
# que hace: ['Reparto']
# conocido: ['']
# año: 1981
# premios: Sin Oscar
# 897. Sarah Hassett Jones
# que hace: ['Reparto']
# conocido: ['Joy']
# año: No data
# premios: Sin oscar
# 898. Astrid Overå
# que hace: ['Reparto', 'Guion']
# conocido: ['Más que nunca', 'Wide Blue Yonder', 'The Frost (La escarcha)', 'Mor Mi']
# año: No data
# premios: Sin oscar
# 899. Beverley Eve
# que hace: ['Reparto']
# conocido: ['Night Junkies', "Don't Worry About Me", 'Nobody the Great', 'The Be All and End All']
# año: No data
# premios: Sin oscar
# 900. Everette Scott Ortiz
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: julio
# premios: Sin oscar
# 901. Paul Gravett
# que hace: ['Arte', 'Reparto']
# conocido: ['Prisoner of War', '2002', '2009', 'Arte(Kuju Brighton)', 'Videojuego']
# año: No data
# premios: Sin oscar
# 902. Michel Voletti
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 903. Helmut Köpping
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['Der Onkel', 'The Making of Futbol', 'Im Auto', '6,3']
# año: No data
# premios: Sin oscar
# 904. Alex Nesic
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1976
# premios: Sin oscar
# 905. Nicolas Besançon
# que hace: ['Reparto']
# conocido: ["Demain dès l'aube"]
# año: No data
# premios: Sin oscar
# 906. Amit Shah
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1981
# premios: Sin Oscar
# 907. Arthur Peyret
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 908. Chris Messina
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1974
# premios: Sin Oscar
# 909. Helen Wilson
# que hace: ['Arte', 'Reparto', 'Vestuario']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 910. Claudio Santamaria
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1974
# premios: Sin Oscar
# 911. Mikaël Gaspar
# que hace: ['Reparto']
# conocido: ['Le sanglot des anges', '2008 • 3 episodios', '2009']
# año: No data
# premios: Sin oscar
# 912. David Roper
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['The Damned United', 'Gente de barrio', '1994–1995 • 87 episodios', '1978–1980 • 26 episodios', 'Chris Hawthorne']
# año: 1944
# premios: Sin oscar
# 913. Lilia Mendoza
# que hace: ['Reparto']
# conocido: ['En el camino', 'Sitiados: México', '2019 • 6 episodios', 'Maestra E.F.', 'Serie de TV']
# año: 1978
# premios: Sin oscar
# 914. Paul Chun
# que hace: ['Reparto', 'Dirección', 'Animación']
# conocido: ['']
# año: 1945
# premios: Sin Oscar
# 915. Erica Leerhsen
# que hace: ['Reparto', 'Producción']
# conocido: ['']
# año: 1976
# premios: Sin Oscar
# 916. Pep Munné
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1953
# premios: Sin Oscar
# 917. Selena Haddad
# que hace: ['Reparto']
# conocido: ['Amerrika']
# año: No data
# premios: Sin oscar
# 918. Shawn Baichoo
# que hace: ['Reparto', 'Equipos adicionales', 'Especialistas']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 919. Ashleigh Sumner
# que hace: ['Reparto', 'Arte']
# conocido: ['']
# año: 1979
# premios: Sin oscar
# 920. Kirsten Barber
# que hace: ['Reparto', 'Guion', 'Vestuario']
# conocido: ['Lauren Is Missing', 'Pets', 'The Mountain, the River and the Road', 'One Shot Film', '2009']
# año: No data
# premios: Sin oscar
# 921. Mackenzie Mowat
# que hace: ['Reparto']
# conocido: ['Novio por una noche', 'Fwd', '2017', '2016', 'Pretty Girl']
# año: 1995
# premios: Sin Oscar
# 922. Jennifer June Ross
# que hace: ['Reparto']
# conocido: ['Dick Night', 'Free Samples', 'Once & For All', '3,0']
# año: No data
# premios: Sin oscar
# 923. Gareth Macleavy
# que hace: ['Sonido', 'Reparto', 'Producción']
# conocido: ['Blaise', '2012', '2015', '6,3']
# año: No data
# premios: Sin oscar
# 924. Régis Royer
# que hace: ['Reparto', 'Equipos adicionales']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 925. Lucie Bourdeu
# que hace: ['Reparto', 'Dirección', 'Edición']
# conocido: ['The Drifters', 'Todo brilla', 'Comme des rois', 'Te comería']
# año: No data
# premios: Sin oscar
# 926. Amy Matthews
# que hace: ['Reparto', 'Guion']
# conocido: ['Have I Got News for You', '2022 • 2 episodios', 'Annie McInnesAnnie', 'Self', 'Self']
# año: No data
# premios: Sin oscar
# 927. Portia
# que hace: ['Reparto', 'Producción', 'Banda sonora']
# conocido: ['']
# año: 1988
# premios: Sin Oscar
# 928. Desmond Harrington
# que hace: ['Reparto']
# conocido: ['']
# año: 1976
# premios: Sin Oscar
# 929. Aaron Mathias
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 930. Keir Gilchrist
# que hace: ['Reparto']
# conocido: ['']
# año: 1992
# premios: Sin Oscar
# 931. Axel Prahl
# que hace: ['Reparto', 'Composición', 'Banda sonora']
# conocido: ['']
# año: 1960
# premios: Sin Oscar
# 932. Ryan Dunn
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: 1977
# premios: Sin Oscar
# 933. Noel Palomaria
# que hace: ['Reparto', 'Producción']
# conocido: ['Hard', 'Dinocroc', 'Strangers Online', 'Sweat']
# año: No data
# premios: Sin oscar
# 934. Yisui Zhao
# que hace: ['Reparto']
# conocido: ['Ciudad de vida y muerte']
# año: No data
# premios: Sin oscar
# 935. Gillian Anderson
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1968
# premios: Ganó 2 premios Primetime Emmy
# 936. James Ramsey
# que hace: ['Reparto']
# conocido: ['Valhalla Rising']
# año: No data
# premios: Sin oscar
# 937. Clara Conzen
# que hace: ['Reparto']
# conocido: ['La granja', 'Das Baby', '2007', 'Becky', 'Película de TV']
# año: 1999
# premios: Sin oscar
# 938. Muzahid Khan
# que hace: ['Reparto', 'Producción', 'Equipos adicionales']
# conocido: ['Right Yaaa Wrong', 'Mumbai Mirror', 'Medal', 'UTOPIA ek mrigtrishna...']
# año: 1985
# premios: Sin oscar
# 939. Justin Daering
# que hace: ['Equipos adicionales', 'Dirección de la segunda unidad o asistencia a dirección', 'Dirección']
# conocido: ['Progeny', '2019', '2019', '2016', '2011']
# año: No data
# premios: Sin Oscar
# 940. Gökay Yildiz
# que hace: ['Reparto']
# conocido: ['Arka Sokaklar', '2008 • 1 episodio', '2009']
# año: No data
# premios: Sin oscar
# 941. Laura Montana
# que hace: ['Reparto']
# conocido: ['A Is for Alice', 'Corto', 'Corto']
# año: No data
# premios: Sin oscar
# 942. Brenda Strong
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1960
# premios: Nominado para 2 premios Primetime Emmy
# 943. Matthias Walter
# que hace: ['Reparto']
# conocido: ['']
# año: 1975
# premios: Sin oscar
# 944. Young Hun Choi
# que hace: ['Dirección', 'Edición']
# conocido: ['Pandora: Beneath the Paradise', '2023 • 16 episodios', 'Dirección', 'Serie de TV', '8,3']
# año: No data
# premios: Sin oscar
# 945. JC Chasez
# que hace: ['Reparto', 'Producción', 'Composición']
# conocido: ['']
# año: 1976
# premios: Sin Oscar
# 946. Jakob Cedergren
# que hace: ['Reparto']
# conocido: ['']
# año: 1973
# premios: Sin Oscar
# 947. Peter Anthony Tambakis
# que hace: ['Reparto']
# conocido: ['']
# año: 1984
# premios: Sin Oscar
# 948. Cécile Laloy
# que hace: ['Reparto']
# conocido: ['Te comería', "D'amour et d'eau fraîche"]
# año: No data
# premios: Sin oscar
# 949. Paula Chirila
# que hace: ['Reparto']
# conocido: ['Zapada, Ceai si Dragoste', 'O secundã de viatã', 'Mangalita', '2020 • 8 episodios', '2006']
# año: No data
# premios: Sin oscar
# 950. Geoffrey Arend
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1978
# premios: Sin Oscar
# 951. Anne Downie
# que hace: ['Reparto']
# conocido: ['Taggart', '1985–2002 • 4 episodios', 'Moira Gemmell', 'Barbara Ross', 'Anna Cullen']
# año: No data
# premios: Sin oscar
# 952. Gene Burns
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ["Ruth's Locket", "Stella's Secret", 'Desdemona: A Love Story', 'Demándame']
# año: No data
# premios: Sin oscar
# 953. Luke Dickson
# que hace: ['Reparto']
# conocido: ['The Spell', 'Delivery of the Dead', '2008']
# año: No data
# premios: Sin oscar
# 954. Christopher Massey
# que hace: ['Reparto', 'Música', 'Banda sonora']
# conocido: ['']
# año: 1990
# premios: Sin Oscar
# 955. Laura Donoughue
# que hace: ['Reparto', 'Equipos adicionales']
# conocido: ['Chronicles of Syntax', '2013 • 6 episodios', '2014', '2011', 'Deborah Teagarden']
# año: No data
# premios: Sin oscar
# 956. Melvil Poupaud
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1973
# premios: Sin Oscar
# 957. Dorka Gryllus
# que hace: ['Reparto', 'Dirección', 'Producción']
# conocido: ['']
# año: 1972
# premios: Sin Oscar
# 958. Peter Zizzo
# que hace: ['Música', 'Composición', 'Reparto']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 959. Ahmed Ahmed
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: 1982
# premios: Ganó 1 premio Óscar
# 960. Mike Cauchon
# que hace: ['Producción', 'Dirección', 'Edición']
# conocido: ['Dirty Rotten Cleaners', '2021 • 8 episodios', '2016 • 1 episodio', 'Producción', 'Serie de TV']
# año: No data
# premios: Sin oscar
# 961. Vikas Anand
# que hace: ['Reparto', 'Guion']
# conocido: ['Sholay', 'Khoon Bhari Maang', 'Darr', 'Kroadh']
# año: No data
# premios: Sin oscar
# 962. Ian McElhinney
# que hace: ['Reparto', 'Dirección', 'Banda sonora']
# conocido: ['']
# año: 1948
# premios: Sin Oscar
# 963. Clement von Franckenstein
# que hace: ['Reparto', 'Equipos adicionales']
# conocido: ['']
# año: 1944
# premios: Sin Oscar
# 964. Nick Ferrin
# que hace: ['Equipos adicionales', 'Reparto']
# conocido: ['']
# año: 1981
# premios: Sin oscar
# 965. Eyüp Agilday
# que hace: ['Reparto']
# conocido: ['Havar']
# año: No data
# premios: Sin oscar
# 966. Adam Baldwin
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1962
# premios: Sin Oscar
# 967. Dominic Kates
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 968. Gary Cherkassky
# que hace: ['Reparto', 'Dirección de la segunda unidad o asistencia a dirección']
# conocido: ['Traveler', '2007 • 1 episodio', '2009', '2008', 'Hot Dog Vendor Sidekick(as Igor Cherkassky)']
# año: 1988
# premios: Sin oscar
# 969. Megumi Ogata
# que hace: ['Reparto', 'Música', 'Banda sonora']
# conocido: ['Neon Genesis Evangelion: The End of Evangelion', 'Evangelion: 3.0+1.01 Thrice Upon a Time', 'Neon Genesis Evangelion: Death & Rebirth', 'Neon Genesis Evangelion', '1995–1996 • 21 episodios']
# año: 1965
# premios: Sin Oscar
# 970. Brienne De Beau
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 971. Alex Hernandez
# que hace: ['Reparto', 'Dirección', 'Producción']
# conocido: ['']
# año: No data
# premios: Nominado a 1 premio BAFTA
# 972. Fayssal Bazzi
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 973. Ward Weemhoff
# que hace: ['Reparto', 'Producción']
# conocido: ['De troon', '2010 • 2 episodios', '2021', '2009', '2012']
# año: No data
# premios: Sin oscar
# 974. Thomas Hedengran
# que hace: ['Reparto']
# conocido: ['']
# año: 1965
# premios: Sin Oscar
# 975. Monique Chaumette
# que hace: ['Reparto']
# conocido: ['']
# año: 1927
# premios: Sin oscar
# 976. Rita Bánczi
# que hace: ['Reparto']
# conocido: ['Little Foxes', 'Little White Lie', '2008']
# año: No data
# premios: Sin oscar
# 977. Andrea Di Stefano
# que hace: ['Reparto', 'Guion', 'Dirección']
# conocido: ['']
# año: 1972
# premios: Sin Oscar
# 978. Scott Winters
# que hace: ['Reparto', 'Guion']
# conocido: ['']
# año: 1965
# premios: Sin oscar
# 979. Chris Gartin
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1968
# premios: Sin Oscar
# 980. Nina Miller
# que hace: No data
# conocido: ['1, 2 oder 3', '2020 • 1 episodio']
# año: No data
# premios: Sin oscar
# 981. Minka Kelly
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1980
# premios: Sin Oscar
# 982. Lisa Joyce
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 983. Russell M. Haeuser
# que hace: ['Reparto', 'Especialistas', 'Equipos adicionales']
# conocido: ['Déjà Vu (Cambiando el pasado)', 'El pacto', '12 trampas', 'Parker']
# año: No data
# premios: Sin oscar
# 984. Christophe Calmel
# que hace: ['Reparto']
# conocido: ["J'ai oublié de te dire", 'Capitán Conan', 'Esteban and Zia in search of the 7 Cities of Gold', '5,2']
# año: No data
# premios: Sin oscar
# 985. Emilio Gutiérrez Caba
# que hace: ['Reparto', 'Equipos adicionales']
# conocido: ['']
# año: 1942
# premios: Sin Oscar
# 986. Toby Marlow
# que hace: ['Reparto', 'Composición', 'Guion']
# conocido: ['Ben Hur', '2010 • 2 episodios', '2021 • 1 episodio', 'La joven de las especias']
# año: 1994
# premios: Sin Oscar
# 987. Ivo Velon
# que hace: ['Reparto', 'Producción']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 988. Naomi Kawase
# que hace: ['Dirección', 'Guion', 'Producción']
# conocido: ['']
# año: 1969
# premios: Sin Oscar
# 989. Deirdre O'Connell
# que hace: ['Reparto']
# conocido: ['']
# año: 1953
# premios: Sin Oscar
# 990. Jessica Biel
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1982
# premios: Nominado para 1 premio Primetime Emmy
# 991. Michael Mandell
# que hace: ['Reparto']
# conocido: ['Philip Morris ¡Te quiero!', 'Noche de fin de año', 'Person of Interest', '2012 • 1 episodio', 'Big Jerry']
# año: 1959
# premios: Sin oscar
# 992. Billy Crudup
# que hace: ['Reparto', 'Producción', 'Banda sonora']
# conocido: ['']
# año: 1968
# premios: Ganó 1 premio Primetime Emmy
# 993. Meera Syal
# que hace: ['Reparto', 'Guion', 'Guion y continuidad']
# conocido: ['']
# año: 1961
# premios: Nominado a 1 premio BAFTA
# 994. Roy Black
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1943
# premios: Sin oscar
# 995. Ellie Haddington
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['Enola Holmes', 'Spies of Warsaw', '2013 • 3 episodios', '2016', '2009']
# año: 1955
# premios: Sin oscar
# 996. Mike Hinkle
# que hace: ['Reparto']
# conocido: ['The Hayden Family Murders', '6,0']
# año: No data
# premios: Sin oscar
# 997. Rei Dan
# que hace: ['Reparto']
# conocido: ['El catador de venenos', 'Kâbê', 'Kansen rettô', 'Nintama Rantarô']
# año: 1971
# premios: Sin Oscar
# 998. Frankie Faison
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1949
# premios: Sin Oscar
# 999. Kerrie Hayes
# que hace: ['Reparto']
# conocido: ['']
# año: 1986
# premios: Nominado a 1 premio BAFTA
# 1000. Henry Dittman
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: diciembre
# premios: Sin Oscar
# 1001. Jason Mulhearn
# que hace: ['Reparto']
# conocido: ["Dead Man's Cards", 'Something Wrong', 'The Be All and End All', "Don't Worry About Me"]
# año: No data
# premios: Sin oscar
#                     0          1  \
# 0         Rachel Bell       1950
# 1     Bjørn Sundquist       1948
# 2         Yejin Jeong    No data
# 3        Chengwei Ren    No data
# 4        Manabu Oshio       1978
# ...               ...        ...
# 996           Rei Dan       1971
# 997    Frankie Faison       1949
# 998      Kerrie Hayes       1986
# 999     Henry Dittman  diciembre
# 1000   Jason Mulhearn    No data
#
#                                                       2  \
# 0     [The Darling Buds of May, 1991–1993 • 16 episo...
# 1                                                    []
# 2                                      [Una vida nueva]
# 3     [You ni cai you jia, Da Xue Wu Hen, Ke ai de Z...
# 4     [Yamato nadeshiko, 2000 • 11 episodios, 2005, ...
# ...                                                 ...
# 996   [El catador de venenos, Kâbê, Kansen rettô, Ni...
# 997                                                  []
# 998                                                  []
# 999                                                  []
# 1000  [Dead Man's Cards, Something Wrong, The Be All...
#
#                                  3                          4
# 0                        [Reparto]                  Sin oscar
# 1                [Reparto, Música]                  Sin Oscar
# 2                        [Reparto]                  Sin oscar
# 3             [Reparto, Dirección]                  Sin Oscar
# 4                        [Reparto]                  Sin oscar
# ...                            ...                        ...
# 996                      [Reparto]                  Sin Oscar
# 997        [Reparto, Banda sonora]                  Sin Oscar
# 998                      [Reparto]  Nominado a 1 premio BAFTA
# 999   [Reparto, Producción, Guion]                  Sin Oscar
# 1000                     [Reparto]                  Sin oscar
#
# [1001 rows x 5 columns]
